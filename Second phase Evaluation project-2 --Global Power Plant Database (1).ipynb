# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import LabelEncoder

# %%
ds=pd.read_csv(r"C:\Users\Sonali\Desktop\Flip Robo internship\Evaluation project phase\Datasets\database_IND.csv")
ds
# Out:
#     country country_long                          name   gppd_idnr  \
# 0       IND        India              ACME Solar Tower  WRI1020239
# 1       IND        India           ADITYA CEMENT WORKS  WRI1019881
# 2       IND        India      AES Saurashtra Windfarms  WRI1026669
# 3       IND        India                   AGARTALA GT  IND0000001
# 4       IND        India                  AKALTARA TPP  IND0000002
# ..      ...          ...                           ...         ...
# 902     IND        India                  YERMARUS TPP  IND0000513
# 903     IND        India  Yelesandra Solar Power Plant  WRI1026222
# 904     IND        India  Yelisirur wind power project  WRI1026776
# 905     IND        India                   ZAWAR MINES  WRI1019901
# 906     IND        India       iEnergy Theni Wind Farm  WRI1026761
#
#      capacity_mw  latitude  longitude primary_fuel other_fuel1 other_fuel2  \
# 0            2.5   28.1839    73.2407        Solar         NaN         NaN
# ...

# %%
ds.sample()
# Out:
#    country country_long                       name   gppd_idnr  capacity_mw  \
# 26     IND        India  Amarsar Solar Power Plant  WRI1026104          1.0
#
#     latitude  longitude primary_fuel other_fuel1 other_fuel2  ...  \
# 26   28.3615    74.2402        Solar         NaN         NaN  ...
#
#     year_of_capacity_data  generation_gwh_2013 generation_gwh_2014  \
# 26                    NaN                  NaN                 NaN
#
#    generation_gwh_2015 generation_gwh_2016 generation_gwh_2017  \
# 26                 NaN                 NaN                 NaN
#
#     generation_gwh_2018  generation_gwh_2019  generation_data_source  \
# 26                  NaN                  NaN                     NaN
#
#     estimated_generation_gwh
# 26                       NaN
#
# [1 rows x 27 columns]

# %%
ds.head()
# Out:
#   country country_long                      name   gppd_idnr  capacity_mw  \
# 0     IND        India          ACME Solar Tower  WRI1020239          2.5
# 1     IND        India       ADITYA CEMENT WORKS  WRI1019881         98.0
# 2     IND        India  AES Saurashtra Windfarms  WRI1026669         39.2
# 3     IND        India               AGARTALA GT  IND0000001        135.0
# 4     IND        India              AKALTARA TPP  IND0000002       1800.0
#
#    latitude  longitude primary_fuel other_fuel1 other_fuel2  ...  \
# 0   28.1839    73.2407        Solar         NaN         NaN  ...
# 1   24.7663    74.6090         Coal         NaN         NaN  ...
# 2   21.9038    69.3732         Wind         NaN         NaN  ...
# 3   23.8712    91.3602          Gas         NaN         NaN  ...
# 4   21.9603    82.4091         Coal         Oil         NaN  ...
#
#    year_of_capacity_data  generation_gwh_2013 generation_gwh_2014  \
# ...

# %%
ds.dtypes
# Out:
# country                      object
# country_long                 object
# name                         object
# gppd_idnr                    object
# capacity_mw                 float64
# latitude                    float64
# longitude                   float64
# primary_fuel                 object
# other_fuel1                  object
# other_fuel2                  object
# other_fuel3                 float64
# commissioning_year          float64
# owner                        object
# source                       object
# url                          object
# geolocation_source           object
# wepp_id                     float64
# year_of_capacity_data       float64
# generation_gwh_2013         float64
# generation_gwh_2014         float64
# generation_gwh_2015         float64
# generation_gwh_2016         float64
# generation_gwh_2017         float64
# generation_gwh_2018         float64
# generation_gwh_2019         float64
# generation_data_source       object
# ...

# %%
ds.nunique()
# Out:
# country                       1
# country_long                  1
# name                        907
# gppd_idnr                   907
# capacity_mw                 361
# latitude                    836
# longitude                   827
# primary_fuel                  8
# other_fuel1                   3
# other_fuel2                   1
# other_fuel3                   0
# commissioning_year           73
# owner                       280
# source                      191
# url                         304
# geolocation_source            3
# wepp_id                       0
# year_of_capacity_data         1
# generation_gwh_2013           0
# generation_gwh_2014         371
# generation_gwh_2015         396
# generation_gwh_2016         403
# generation_gwh_2017         408
# generation_gwh_2018         410
# generation_gwh_2019           0
# generation_data_source        1
# estimated_generation_gwh      0
# dtype: int64

# %% [markdown]
# from the above unique values, we can see that Name has 907 unique values, which are not really important in data analysis, so here we can remove thename column

# %%
ds.drop(['name'],axis=1,inplace=True)

# %%
le=LabelEncoder()

# %%
ds['country']=le.fit_transform(ds['country'])

# %%
ds['country_long']=le.fit_transform(ds['country_long'])

# %%
ds['primary_fuel']=le.fit_transform(ds['primary_fuel'])

# %%
ds['other_fuel1']=le.fit_transform(ds['other_fuel1'])

# %%
ds['other_fuel2']=le.fit_transform(ds['other_fuel2'])

# %%
ds['owner']=le.fit_transform(ds['owner'])

# %%
ds['source']=le.fit_transform(ds['source'])

# %%
ds['url']=le.fit_transform(ds['url'])

# %%
ds
# Out:
#      country  country_long   gppd_idnr  capacity_mw  latitude  longitude  \
# 0          0             0  WRI1020239          2.5   28.1839    73.2407
# 1          0             0  WRI1019881         98.0   24.7663    74.6090
# 2          0             0  WRI1026669         39.2   21.9038    69.3732
# 3          0             0  IND0000001        135.0   23.8712    91.3602
# 4          0             0  IND0000002       1800.0   21.9603    82.4091
# ..       ...           ...         ...          ...       ...        ...
# 902        0             0  IND0000513       1600.0   16.2949    77.3568
# 903        0             0  WRI1026222          3.0   12.8932    78.1654
# 904        0             0  WRI1026776         25.5   15.2758    75.5811
# 905        0             0  WRI1019901         80.0   24.3500    73.7477
# 906        0             0  WRI1026761         16.5    9.9344    77.4768
#
#      primary_fuel  other_fuel1  other_fuel2  other_fuel3  ...  \
# ...

# %%
ds['geolocation_source']=le.fit_transform(ds['geolocation_source'])

# %%
ds['generation_data_source']=le.fit_transform(ds['generation_data_source'])

# %%
ds.isnull().sum()
# Out:
# country                       0
# country_long                  0
# gppd_idnr                     0
# capacity_mw                   0
# latitude                     46
# longitude                    46
# primary_fuel                  0
# other_fuel1                   0
# other_fuel2                   0
# other_fuel3                 907
# commissioning_year          380
# owner                         0
# source                        0
# url                           0
# geolocation_source            0
# wepp_id                     907
# year_of_capacity_data       388
# generation_gwh_2013         907
# generation_gwh_2014         509
# generation_gwh_2015         485
# generation_gwh_2016         473
# generation_gwh_2017         467
# generation_gwh_2018         459
# generation_gwh_2019         907
# generation_data_source        0
# estimated_generation_gwh    907
# dtype: int64

# %%
ds['primary_fuel'].nunique
# Out:
# <bound method IndexOpsMixin.nunique of 0      6
# 1      1
# 2      7
# 3      2
# 4      1
#       ..
# 902    1
# 903    6
# 904    7
# 905    1
# 906    7
# Name: primary_fuel, Length: 907, dtype: int32>

# %%
sns.heatmap(ds.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# From the above heatmap, we can see that, there are many null values present in the data. Now, we have to fill all the null values using fillna method for all emply/null values.

# %%
ds=ds.fillna(ds['latitude'].mode())

# %%
ds=ds.fillna(ds['longitude'].mean())

# %% [markdown]
# As we can see from the isnull columnwise values, there are all null values present in the other_fuel3, so the column is not at all usefull for analysis purpose. So, we can drop it for smooth processing.

# %%
ds.drop(['other_fuel3'],axis=1,inplace=True)

# %%
ds.drop(['gppd_idnr'],axis=1,inplace=True)

# %%
ds=ds.fillna(ds['commissioning_year'].mode())

# %%
ds=ds.fillna(ds['year_of_capacity_data'].mode())

# %%
ds.drop(['wepp_id'],axis=1,inplace=True)

# %% [markdown]
# As we can see in the above columnwise null values, wepp_id column is not having any value in it, so it is better to remove it from the data'

# %%
ds.drop(['generation_gwh_2013'],axis=1,inplace=True)

# %% [markdown]
# As we can see in the above columnwise null values, generation_gwh_2013 column is totally empty, so it is better to remove it from the data.

# %%
ds=ds.fillna(ds['generation_gwh_2014'].mean())

# %%
ds=ds.fillna(ds['generation_gwh_2015'].mean())

# %%
ds=ds.fillna(ds['generation_gwh_2016'].mean())

# %%
ds=ds.fillna(ds['generation_gwh_2017'].mean())

# %%
ds=ds.fillna(ds['generation_gwh_2018'].mean())

# %% [markdown]
# As we can see in the above columnwise null values, generation_gwh_2019 column is totally empty, so it is better to remove it from the data.

# %%
ds.drop(['generation_gwh_2019'],axis=1,inplace=True)

# %% [markdown]
# As from the above null values, we can observe that, column estimated_generation_gwh is null, so we can remove it from the data for smooth processing.

# %%
ds['generation_data_source']=le.fit_transform(ds['generation_data_source'])

# %%
ds=ds.fillna(ds['generation_data_source'].mode())

# %%
ds.drop(['estimated_generation_gwh'],axis=1,inplace=True)

# %%
ds
# Out:
#      country  country_long  capacity_mw  latitude  longitude  primary_fuel  \
# 0          0             0          2.5   28.1839    73.2407             6
# 1          0             0         98.0   24.7663    74.6090             1
# 2          0             0         39.2   21.9038    69.3732             7
# 3          0             0        135.0   23.8712    91.3602             2
# 4          0             0       1800.0   21.9603    82.4091             1
# ..       ...           ...          ...       ...        ...           ...
# 902        0             0       1600.0   16.2949    77.3568             1
# 903        0             0          3.0   12.8932    78.1654             6
# 904        0             0         25.5   15.2758    75.5811             7
# 905        0             0         80.0   24.3500    73.7477             1
# 906        0             0         16.5    9.9344    77.4768             7
#
# ...

# %%
ds.isnull().sum()
# Out:
# country                   0
# country_long              0
# capacity_mw               0
# latitude                  0
# longitude                 0
# primary_fuel              0
# other_fuel1               0
# other_fuel2               0
# commissioning_year        0
# owner                     0
# source                    0
# url                       0
# geolocation_source        0
# year_of_capacity_data     0
# generation_gwh_2014       0
# generation_gwh_2015       0
# generation_gwh_2016       0
# generation_gwh_2017       0
# generation_gwh_2018       0
# generation_data_source    0
# dtype: int64

# %%
sns.heatmap(ds.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# The above heatmap, shows that now, there are no null values present in the data.

# %%
ds.describe()
# Out:
#        country  country_long  capacity_mw    latitude   longitude  \
# count    907.0         907.0   907.000000  907.000000  907.000000
# mean       0.0           0.0   326.223755   24.051591   77.464907
# std        0.0           0.0   590.085456   13.767659    4.812291
# min        0.0           0.0     0.000000    8.168900   68.644700
# 25%        0.0           0.0    16.725000   17.072000   74.388900
# 50%        0.0           0.0    59.200000   22.142100   76.979200
# 75%        0.0           0.0   385.250000   26.753750   79.206100
# max        0.0           0.0  4760.000000   77.464907   95.408000
#
#        primary_fuel  other_fuel1  other_fuel2  commissioning_year       owner  \
# count    907.000000   907.000000   907.000000          907.000000  907.000000
# mean       3.206174     2.777288     0.998897         1192.837558  227.476295
# std        2.280652     0.429348     0.033204          947.735155   83.924045
# ...

# %% [markdown]
# From the above description, we can observe that, mean is larger than median in some features, which means that the skewness is present in the data.
#
# We can also observe the large difference between max and 75% values, which shows that the outliers are present in the data.
#
# We can also see the min, standard deviation,count and min values from the above description.

# %%
sns.heatmap(ds.describe(),annot=True, linewidth=0.5, linecolor='black', cmap='Spectral')
# Out:
# <AxesSubplot:>

# %%
ds.corr()
# Out:
#                         country  country_long  capacity_mw  latitude  \
# country                     NaN           NaN          NaN       NaN
# country_long                NaN           NaN          NaN       NaN
# capacity_mw                 NaN           NaN     1.000000 -0.070677
# latitude                    NaN           NaN    -0.070677  1.000000
# longitude                   NaN           NaN     0.195882  0.016056
# primary_fuel                NaN           NaN    -0.380395  0.109256
# other_fuel1                 NaN           NaN    -0.606289  0.040625
# other_fuel2                 NaN           NaN     0.003731  0.021410
# commissioning_year          NaN           NaN     0.414810  0.079063
# owner                       NaN           NaN     0.304322  0.037969
# source                      NaN           NaN    -0.242122 -0.043208
# url                         NaN           NaN    -0.243830  0.020230
# geolocation_source          NaN           NaN     0.183419  0.116580
# ...

# %%
sns.heatmap(ds.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
ds.dtypes
# Out:
# country                     int32
# country_long                int32
# capacity_mw               float64
# latitude                  float64
# longitude                 float64
# primary_fuel                int32
# other_fuel1                 int32
# other_fuel2                 int32
# commissioning_year        float64
# owner                       int32
# source                      int32
# url                         int32
# geolocation_source          int32
# year_of_capacity_data     float64
# generation_gwh_2014       float64
# generation_gwh_2015       float64
# generation_gwh_2016       float64
# generation_gwh_2017       float64
# generation_gwh_2018       float64
# generation_data_source      int64
# dtype: object

# %% [markdown]
# As the country and country_long columns are not that much useful in the analysis, we can drop them.

# %%
ds.drop(['country','country_long'],axis=1,inplace=True)

# %% [markdown]
# From the above heatmap, we can see that some columns are in positive relation with other columns.

# %%
sns.distplot(ds['longitude'],ds['capacity_mw'],'bins'==20)
# Out:
# <AxesSubplot:xlabel='longitude', ylabel='Density'>

# %%
sns.distplot(ds['longitude'],ds['primary_fuel'],'bins'==20)
# Out:
# <AxesSubplot:xlabel='longitude', ylabel='Density'>

# %%
sns.distplot(ds['latitude'],ds['capacity_mw'],'bins'==20)
# Out:
# <AxesSubplot:xlabel='latitude', ylabel='Density'>

# %%
sns.distplot(ds['latitude'],ds['primary_fuel'],'bins'==20)
# Out:
# <AxesSubplot:xlabel='latitude', ylabel='Density'>

# %%
sns.distplot(ds['primary_fuel'],ds['capacity_mw'],'bins'==20)
# Out:
# <AxesSubplot:xlabel='primary_fuel', ylabel='Density'>

# %%
sns.distplot(ds['other_fuel1'],ds['capacity_mw'],'bins'==20)
# Out:
# <AxesSubplot:xlabel='other_fuel1', ylabel='Density'>

# %%
sns.distplot(ds['other_fuel2'],ds['capacity_mw'],'bins'==20)
# Out:
# <AxesSubplot:xlabel='other_fuel2', ylabel='Density'>

# %%
sns.distplot(ds['latitude'],ds['primary_fuel'],'bins'==20)
# Out:
# <AxesSubplot:xlabel='latitude', ylabel='Density'>

# %%
sns.distplot(ds['latitude'],ds['primary_fuel'],'bins'==20)
# Out:
# <AxesSubplot:xlabel='latitude', ylabel='Density'>

# %%
sns.distplot(ds['owner'],ds['capacity_mw'],'bins'==20)
# Out:
# <AxesSubplot:xlabel='owner', ylabel='Density'>

# %%
sns.distplot(ds['latitude'],ds['primary_fuel'],'bins'==20)
# Out:
# <AxesSubplot:xlabel='latitude', ylabel='Density'>

# %%
sns.distplot(ds['source'],ds['capacity_mw'],'bins'==20)
# Out:
# <AxesSubplot:xlabel='source', ylabel='Density'>

# %%
sns.distplot(ds['latitude'],ds['primary_fuel'],'bins'==20)
# Out:
# <AxesSubplot:xlabel='latitude', ylabel='Density'>

# %%
sns.distplot(ds['url'],ds['capacity_mw'],'bins'==20)
# Out:
# <AxesSubplot:xlabel='url', ylabel='Density'>

# %%
sns.distplot(ds['latitude'],ds['primary_fuel'],'bins'==20)
# Out:
# <AxesSubplot:xlabel='latitude', ylabel='Density'>

# %%
sns.distplot(ds['geolocation_source'],ds['capacity_mw'],'bins'==20)
# Out:
# <AxesSubplot:xlabel='geolocation_source', ylabel='Density'>

# %%
sns.distplot(ds['geolocation_source'],ds['primary_fuel'],'bins'==20)
# Out:
# <AxesSubplot:xlabel='geolocation_source', ylabel='Density'>

# %%
sns.distplot(ds['year_of_capacity_data'],ds['primary_fuel'],'bins'==20)
# Out:
# <AxesSubplot:xlabel='year_of_capacity_data', ylabel='Density'>

# %%
sns.distplot(ds['year_of_capacity_data'],ds['capacity_mw'],'bins'==20)
# Out:
# <AxesSubplot:xlabel='year_of_capacity_data', ylabel='Density'>

# %%
sns.distplot(ds['generation_gwh_2014'],ds['capacity_mw'],'bins'==20)
# Out:
# <AxesSubplot:xlabel='generation_gwh_2014', ylabel='Density'>

# %%
sns.distplot(ds['generation_gwh_2014'],ds['primary_fuel'],'bins'==20)
# Out:
# <AxesSubplot:xlabel='generation_gwh_2014', ylabel='Density'>

# %%
sns.distplot(ds['generation_gwh_2015'],ds['primary_fuel'],'bins'==20)
# Out:
# <AxesSubplot:xlabel='generation_gwh_2015', ylabel='Density'>

# %%
sns.distplot(ds['generation_gwh_2015'],ds['capacity_mw'],'bins'==20)
# Out:
# <AxesSubplot:xlabel='generation_gwh_2015', ylabel='Density'>

# %%
sns.distplot(ds['generation_gwh_2016'],ds['primary_fuel'],'bins'==20)
# Out:
# <AxesSubplot:xlabel='generation_gwh_2016', ylabel='Density'>

# %%
sns.distplot(ds['generation_gwh_2016'],ds['capacity_mw'],'bins'==20)
# Out:
# <AxesSubplot:xlabel='generation_gwh_2016', ylabel='Density'>

# %%
sns.distplot(ds['generation_gwh_2017'],ds['primary_fuel'],'bins'==20)
# Out:
# <AxesSubplot:xlabel='generation_gwh_2017', ylabel='Density'>

# %%
sns.distplot(ds['generation_gwh_2017'],ds['capacity_mw'],'bins'==20)
# Out:
# <AxesSubplot:xlabel='generation_gwh_2017', ylabel='Density'>

# %%
sns.distplot(ds['generation_gwh_2018'],ds['primary_fuel'],'bins'==20)
# Out:
# <AxesSubplot:xlabel='generation_gwh_2018', ylabel='Density'>

# %%
sns.distplot(ds['generation_gwh_2018'],ds['capacity_mw'],'bins'==20)
# Out:
# <AxesSubplot:xlabel='generation_gwh_2018', ylabel='Density'>

# %%
sns.distplot(ds['generation_data_source'],ds['primary_fuel'],'bins'==20)
# Out:
# <AxesSubplot:xlabel='generation_data_source', ylabel='Density'>

# %%
sns.distplot(ds['generation_data_source'],ds['capacity_mw'],'bins'==20)
# Out:
# <AxesSubplot:xlabel='generation_data_source', ylabel='Density'>

# %%
ds.skew()
# Out:
# capacity_mw                3.123576
# latitude                   2.828497
# longitude                  1.141881
# primary_fuel               0.472251
# other_fuel1               -1.626786
# other_fuel2              -30.116441
# commissioning_year        -0.328462
# owner                     -1.373940
# source                     1.827373
# url                        1.510537
# geolocation_source        -1.920302
# year_of_capacity_data     -0.292409
# generation_gwh_2014        5.028221
# generation_gwh_2015        5.301864
# generation_gwh_2016        5.023714
# generation_gwh_2017        5.019796
# generation_gwh_2018        4.882505
# generation_data_source    -0.019880
# dtype: float64

# %%
ds['latitude']=np.sqrt(ds['latitude'])

# %%
ds['longitude']=np.sqrt(ds['longitude'])

# %%
ds['generation_gwh_2014']=np.cbrt(ds['generation_gwh_2014'])

# %%
ds['generation_gwh_2015']=np.cbrt(ds['generation_gwh_2015'])

# %%
ds['generation_gwh_2016']=np.cbrt(ds['generation_gwh_2016'])

# %%
ds['generation_gwh_2017']=np.cbrt(ds['generation_gwh_2017'])

# %%
ds['generation_gwh_2018']=np.cbrt(ds['generation_gwh_2018'])

# %%
ds.skew()
# Out:
# capacity_mw                3.123576
# latitude                   1.834809
# longitude                  1.036861
# primary_fuel               0.472251
# other_fuel1               -1.626786
# other_fuel2              -30.116441
# commissioning_year        -0.328462
# owner                     -1.373940
# source                     1.827373
# url                        1.510537
# geolocation_source        -1.920302
# year_of_capacity_data     -0.292409
# generation_gwh_2014        1.798241
# generation_gwh_2015        1.766092
# generation_gwh_2016        1.689162
# generation_gwh_2017        1.612479
# generation_gwh_2018        1.591182
# generation_data_source    -0.019880
# dtype: float64

# %%
ds['latitude']=np.cbrt(ds['latitude'])

# %%
ds['longitude']=np.cbrt(ds['longitude'])

# %%
ds['source']=np.cbrt(ds['source'])

# %%
ds['url']=np.cbrt(ds['url'])

# %%
ds['generation_gwh_2014']=np.cbrt(ds['generation_gwh_2014'])

# %%
ds['generation_gwh_2015']=np.cbrt(ds['generation_gwh_2015'])

# %%
ds['generation_gwh_2016']=np.cbrt(ds['generation_gwh_2016'])

# %%
ds['generation_gwh_2017']=np.cbrt(ds['generation_gwh_2017'])

# %%
ds.skew()
# Out:
# capacity_mw                3.123576
# latitude                   1.061462
# longitude                  0.967550
# primary_fuel               0.472251
# other_fuel1               -1.626786
# other_fuel2              -30.116441
# commissioning_year        -0.328462
# owner                     -1.373940
# source                     1.323520
# url                        0.615432
# geolocation_source        -1.920302
# year_of_capacity_data     -0.292409
# generation_gwh_2014       -0.821210
# generation_gwh_2015       -0.744899
# generation_gwh_2016       -0.814433
# generation_gwh_2017       -0.839477
# generation_gwh_2018        1.591182
# generation_data_source    -0.019880
# dtype: float64

# %% [markdown]
# The above plots shows the presence of skewness in some features.

# %% [markdown]
# Now, we will proceed further and check the presence of outliers with the help of boxplot.

# %%
ds.plot.box()
# Out:
# <AxesSubplot:>

# %%
ds['latitude'].plot.box()
# Out:
# <AxesSubplot:>

# %%
ds['longitude'].plot.box()
# Out:
# <AxesSubplot:>

# %%
ds['primary_fuel'].plot.box()
# Out:
# <AxesSubplot:>

# %%
ds['capacity_mw'].plot.box()
# Out:
# <AxesSubplot:>

# %%
ds['other_fuel1'].plot.box()
# Out:
# <AxesSubplot:>

# %%
ds['other_fuel2'].plot.box()
# Out:
# <AxesSubplot:>

# %%
ds['commissioning_year'].plot.box()
# Out:
# <AxesSubplot:>

# %%
ds['owner'].plot.box()
# Out:
# <AxesSubplot:>

# %%
ds['source'].plot.box()
# Out:
# <AxesSubplot:>

# %%
ds['url'].plot.box()
# Out:
# <AxesSubplot:>

# %%
ds['geolocation_source'].plot.box()
# Out:
# <AxesSubplot:>

# %%
ds['year_of_capacity_data'].plot.box()
# Out:
# <AxesSubplot:>

# %%
ds['generation_gwh_2014'].plot.box()
# Out:
# <AxesSubplot:>

# %%
ds['generation_gwh_2015'].plot.box()
# Out:
# <AxesSubplot:>

# %%
ds['generation_gwh_2016'].plot.box()
# Out:
# <AxesSubplot:>

# %%
ds['generation_gwh_2017'].plot.box()
# Out:
# <AxesSubplot:>

# %%
ds['generation_gwh_2018'].plot.box()
# Out:
# <AxesSubplot:>

# %%
ds['generation_data_source'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# From the above boxplots, it is confirmed that the outliers are present in the data.

# %%
from scipy.stats import zscore
outliers=ds[['capacity_mw',
       'latitude', 'longitude', 'primary_fuel', 'other_fuel1', 'other_fuel2',
       'commissioning_year', 'owner', 'source', 'url',
       'geolocation_source','year_of_capacity_data',
        'generation_gwh_2014', 'generation_gwh_2015',
       'generation_gwh_2016', 'generation_gwh_2017', 'generation_gwh_2018',
        'generation_data_source']]
z=np.abs(zscore(outliers))
z
# Out:
#      capacity_mw  latitude  longitude  primary_fuel  other_fuel1  other_fuel2  \
# 0       0.548908  0.568198   0.896071      1.225688     0.519008     0.033223
# 1       0.386977  0.272077   0.592793      0.967877     0.519008     0.033223
# 2       0.486679  0.003434   1.779578      1.664401     0.519008     0.033223
# 3       0.324240  0.188912   2.787760      0.529164     0.519008     0.033223
# 4       2.498942  0.002287   1.052521      0.967877     1.811388     0.033223
# ..           ...       ...        ...           ...          ...          ...
# 902     2.159821  0.644279   0.002503      0.967877     1.811388     0.033223
# 903     0.548060  1.129618   0.174325      1.225688     0.519008     0.033223
# 904     0.509909  0.780039   0.380135      1.664401     0.519008     0.033223
# 905     0.417498  0.233715   0.783150      0.967877     0.519008     0.033223
# 906     0.525169  1.648155   0.028097      1.664401     0.519008     0.033223
#
# ...

# %%
np.where(z>3)
# Out:
# (array([ 14,  15,  15,  23,  25,  42,  45,  47,  59,  59,  67,  72,  72,
#          72,  72,  72,  86,  86,  88,  97, 106, 143, 143, 147, 160, 160,
#         160, 168, 168, 178, 179, 183, 192, 201, 204, 204, 204, 204, 208,
#         209, 209, 223, 223, 223, 224, 224, 224, 224, 237, 244, 250, 259,
#         259, 275, 275, 275, 277, 277, 308, 308, 312, 312, 323, 329, 330,
#         332, 332, 332, 332, 332, 333, 336, 340, 358, 358, 358, 360, 363,
#         364, 364, 375, 385, 386, 416, 418, 420, 420, 420, 420, 420, 422,
#         427, 430, 435, 435, 435, 435, 435, 440, 448, 460, 466, 468, 470,
#         477, 477, 477, 477, 478, 479, 480, 482, 483, 493, 493, 494, 494,
#         502, 519, 525, 525, 525, 525, 538, 540, 545, 547, 547, 548, 563,
#         565, 569, 569, 569, 569, 577, 585, 585, 585, 590, 628, 628, 638,
#         646, 646, 648, 648, 650, 650, 650, 650, 655, 657, 657, 660, 674,
#         680, 683, 683, 683, 684, 690, 695, 695, 705, 711, 712, 724, 726,
# ...

# %%
z.iloc[15,13]
# Out:
# 2.082413921958601

# %%
ds1=ds[(z<3).all(axis=1)]
ds1
# Out:
#      capacity_mw  latitude  longitude  primary_fuel  other_fuel1  other_fuel2  \
# 0            2.5  1.744483   2.045465             6            3            1
# 1           98.0  1.707301   2.051785             1            3            1
# 2           39.2  1.672707   2.027054             7            3            1
# 3          135.0  1.696859   2.122232             2            3            1
# 4         1800.0  1.673425   2.086072             1            2            1
# ..           ...       ...        ...           ...          ...          ...
# 902       1600.0  1.592240   2.064190             1            2            1
# 903          3.0  1.531299   2.067771             6            3            1
# 904         25.5  1.575194   2.056217             7            3            1
# 905         80.0  1.702484   2.047818             1            3            1
# 906         16.5  1.466190   2.064724             7            3            1
#
# ...

# %% [markdown]
# After finding the outliers through zscore method,we have cleared those and the now we have a new dataset.

# %%
print('Old data shape',ds.shape)
print('New data shape',ds1.shape)
# Out:
# Old data shape (907, 18)
# New data shape (772, 18)

# %%
print('Data loss percentage',((ds.shape[0]-ds1.shape[0])/ds.shape[0])*100)
# Out:
# Data loss percentage 14.884233737596473

# %% [markdown]
# As the above data loss is not affordable, we will check the presence of outliers with the help of IQR method.

# %%
Q1=ds1.quantile(.25)
Q3=ds1.quantile(.75)
IQR=Q3-Q1
IQR
# Out:
# capacity_mw                306.500000
# latitude                     0.123528
# longitude                    0.021394
# primary_fuel                 5.000000
# other_fuel1                  0.000000
# other_fuel2                  0.000000
# commissioning_year        1923.535093
# owner                      108.000000
# source                       1.074367
# url                          1.178575
# geolocation_source           0.000000
# year_of_capacity_data     1941.535093
# generation_gwh_2014          0.399808
# generation_gwh_2015          0.421268
# generation_gwh_2016          0.441462
# generation_gwh_2017          0.467886
# generation_gwh_2018          4.580589
# generation_data_source       1.000000
# dtype: float64

# %%
ds1_new=ds1[(z<3).all(axis=1)]
ds1_new
# Out:
#      capacity_mw  latitude  longitude  primary_fuel  other_fuel1  other_fuel2  \
# 0            2.5  1.744483   2.045465             6            3            1
# 1           98.0  1.707301   2.051785             1            3            1
# 2           39.2  1.672707   2.027054             7            3            1
# 3          135.0  1.696859   2.122232             2            3            1
# 4         1800.0  1.673425   2.086072             1            2            1
# ..           ...       ...        ...           ...          ...          ...
# 902       1600.0  1.592240   2.064190             1            2            1
# 903          3.0  1.531299   2.067771             6            3            1
# 904         25.5  1.575194   2.056217             7            3            1
# 905         80.0  1.702484   2.047818             1            3            1
# 906         16.5  1.466190   2.064724             7            3            1
#
# ...

# %%
plt.figure(figsize=(25,20))
p=1
for i in outliers:
    if p<=18:
        ax=plt.subplot(5,4,p)
        sns.distplot(ds[i],color='r')
        plt.xlabel(i,fontsize=15)
    p+=1
plt.show()

# %% [markdown]
# Here, we have cleared all the outliers from the data using zscore and IQR method. We can see from the above plots, all the features are showing almost normal distribution.

# %%
plt.figure(figsize=(20,16))
plt.subplot(6,4,3)
sns.histplot(ds['primary_fuel'],kde=True)
plt.show()

# %%
plt.figure(figsize=(20,16))
plt.subplot(6,4,3)
sns.histplot(ds['capacity_mw'],kde=True)
plt.show()

# %%
ds1_new.skew()
# Out:
# capacity_mw               1.972432
# latitude                 -0.653842
# longitude                 0.850278
# primary_fuel              0.401122
# other_fuel1              -1.558785
# other_fuel2               0.000000
# commissioning_year       -0.139977
# owner                    -1.222329
# source                    1.181689
# url                       0.705439
# geolocation_source       -1.933141
# year_of_capacity_data    -0.119616
# generation_gwh_2014       1.117049
# generation_gwh_2015       1.063851
# generation_gwh_2016       1.091652
# generation_gwh_2017       1.005048
# generation_gwh_2018       1.382097
# generation_data_source   -0.161456
# dtype: float64

# %%
sns.distplot(ds1_new['primary_fuel'],color='b',kde_kws={'shade':True},hist=False)
# Out:
# <AxesSubplot:xlabel='primary_fuel', ylabel='Density'>

# %%
sns.distplot(ds1_new['capacity_mw'],color='b',kde_kws={'shade':True},hist=False)
# Out:
# <AxesSubplot:xlabel='capacity_mw', ylabel='Density'>

# %%
ds1_new
# Out:
#      capacity_mw  latitude  longitude  primary_fuel  other_fuel1  other_fuel2  \
# 0            2.5  1.744483   2.045465             6            3            1
# 1           98.0  1.707301   2.051785             1            3            1
# 2           39.2  1.672707   2.027054             7            3            1
# 3          135.0  1.696859   2.122232             2            3            1
# 4         1800.0  1.673425   2.086072             1            2            1
# ..           ...       ...        ...           ...          ...          ...
# 902       1600.0  1.592240   2.064190             1            2            1
# 903          3.0  1.531299   2.067771             6            3            1
# 904         25.5  1.575194   2.056217             7            3            1
# 905         80.0  1.702484   2.047818             1            3            1
# 906         16.5  1.466190   2.064724             7            3            1
#
# ...

# %%
ds1_new.columns
# Out:
# Index(['capacity_mw', 'latitude', 'longitude', 'primary_fuel', 'other_fuel1',
#        'other_fuel2', 'commissioning_year', 'owner', 'source', 'url',
#        'geolocation_source', 'year_of_capacity_data', 'generation_gwh_2014',
#        'generation_gwh_2015', 'generation_gwh_2016', 'generation_gwh_2017',
#        'generation_gwh_2018', 'generation_data_source'],
#       dtype='object')

# %%
columns_new=['capacity_mw','primary_fuel','latitude', 'longitude','other_fuel1',
       'other_fuel2', 'commissioning_year', 'owner', 'source', 'url',
       'geolocation_source', 'year_of_capacity_data', 'generation_gwh_2014',
       'generation_gwh_2015', 'generation_gwh_2016', 'generation_gwh_2017',
       'generation_gwh_2018', 'generation_data_source']

# %%
ds1_new = ds1_new.reindex(columns=columns_new)
ds1_new
# Out:
#      capacity_mw  primary_fuel  latitude  longitude  other_fuel1  other_fuel2  \
# 0            2.5             6  1.744483   2.045465            3            1
# 1           98.0             1  1.707301   2.051785            3            1
# 2           39.2             7  1.672707   2.027054            3            1
# 3          135.0             2  1.696859   2.122232            3            1
# 4         1800.0             1  1.673425   2.086072            2            1
# ..           ...           ...       ...        ...          ...          ...
# 902       1600.0             1  1.592240   2.064190            2            1
# 903          3.0             6  1.531299   2.067771            3            1
# 904         25.5             7  1.575194   2.056217            3            1
# 905         80.0             1  1.702484   2.047818            3            1
# 906         16.5             7  1.466190   2.064724            3            1
#
# ...

# %%
x=ds1_new.iloc[:,2:]
x
# Out:
#      latitude  longitude  other_fuel1  other_fuel2  commissioning_year  owner  \
# 0    1.744483   2.045465            3            1         2011.000000    229
# 1    1.707301   2.051785            3            1           77.464907    258
# 2    1.672707   2.027054            3            1           77.464907      2
# 3    1.696859   2.122232            3            1         2004.000000    280
# 4    1.673425   2.086072            2            1         2015.000000    280
# ..        ...        ...          ...          ...                 ...    ...
# 902  1.592240   2.064190            2            1         2016.000000    280
# 903  1.531299   2.067771            3            1           77.464907    114
# 904  1.575194   2.056217            3            1           77.464907    280
# 905  1.702484   2.047818            3            1           77.464907     91
# 906  1.466190   2.064724            3            1           77.464907    279
#
# ...

# %%
y=ds1_new.iloc[:,0:2]
y
# Out:
#      capacity_mw  primary_fuel
# 0            2.5             6
# 1           98.0             1
# 2           39.2             7
# 3          135.0             2
# 4         1800.0             1
# ..           ...           ...
# 902       1600.0             1
# 903          3.0             6
# 904         25.5             7
# 905         80.0             1
# 906         16.5             7
#
# [772 rows x 2 columns]

# %%
x.shape
# Out:
# (772, 16)

# %%
y.shape
# Out:
# (772, 2)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif=pd.DataFrame()
vif['VIF values']=[variance_inflation_factor(x.values,i)for i in range(len(x.columns))]
vif['Features']=x.columns
vif
# Out:
#       VIF values                Features
# 0       1.130730                latitude
# 1       1.352595               longitude
# 2       2.168596             other_fuel1
# 3   16259.205505             other_fuel2
# 4      48.162463      commissioning_year
# 5       3.026801                   owner
# 6       2.135614                  source
# 7       1.956194                     url
# 8       1.648664      geolocation_source
# 9      57.994373   year_of_capacity_data
# 10      6.425940     generation_gwh_2014
# 11     12.331945     generation_gwh_2015
# 12     26.441375     generation_gwh_2016
# 13     26.080081     generation_gwh_2017
# 14     15.209724     generation_gwh_2018
# 15      5.191650  generation_data_source

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=42)

# %%
x_train.shape
# Out:
# (540, 16)

# %%
x_test.shape
# Out:
# (232, 16)

# %%
y_train.shape
# Out:
# (540, 2)

# %%
y_test.shape
# Out:
# (232, 2)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_squared_error

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
pred_lr=lr.predict(x_test)
pred_lr
# Out:
# array([[ 1.31573547e+03,  1.12323072e+00],
#        [ 2.57557707e+01,  4.53774751e+00],
#        [ 6.85980441e+01,  7.45429068e+00],
#        [ 6.13354830e+01,  5.68649212e+00],
#        [-1.47466857e+02,  2.89570267e+00],
#        [ 4.75338320e+02,  3.00306503e+00],
#        [ 4.50832179e+02,  2.71448357e+00],
#        [ 3.09519702e+01,  6.89413117e+00],
#        [ 8.41401155e+01,  5.88883148e+00],
#        [ 7.70074654e+01, -2.68116141e-01],
#        [ 3.53066829e+02,  3.07750216e+00],
#        [ 1.08788574e+01,  3.18614684e+00],
#        [ 4.89390171e+00,  2.98841861e+00],
#        [ 8.53126059e+02,  1.28171211e+00],
#        [ 4.26018206e+01,  3.68614687e+00],
#        [ 6.22103719e+01,  7.10654672e+00],
#        [ 8.68572447e+02,  1.15212652e+00],
#        [ 4.89026974e+01,  4.44179954e+00],
#        [ 3.33046942e+01,  8.27072752e+00],
#        [-1.88183098e+02,  3.49759988e+00],
#        [ 7.31525466e+02,  1.04076457e+00],
#        [ 4.65314503e+02,  2.74444517e+00],
# ...

# %%
print('r2 score:',r2_score(y_test,pred_lr))
print('mean_squared_error:', mean_squared_error(y_test,pred_lr))
print('root mean_squared_error:',np.sqrt(mean_squared_error(y_test,pred_lr)))
# Out:
# r2 score: 0.7880317643446388
# mean_squared_error: 26844.27763474433
# root mean_squared_error: 163.84223397751975

# %%
from sklearn.ensemble import RandomForestRegressor
rfr=RandomForestRegressor()
rfr.fit(x_train,y_train)
pred_rfr=rfr.predict(x_test)
pred_rfr
# Out:
# array([[1.4809900e+03, 1.4000000e+00],
#        [9.4290000e+00, 6.0000000e+00],
#        [6.1384500e+01, 6.8800000e+00],
#        [3.5466500e+01, 6.3600000e+00],
#        [6.5712001e+02, 2.3200000e+00],
#        [2.8818971e+02, 2.5300000e+00],
#        [2.9506546e+02, 1.7200000e+00],
#        [1.0057000e+01, 6.0000000e+00],
#        [1.8739500e+01, 6.8800000e+00],
#        [4.1162600e+01, 4.0000000e-01],
#        [1.6884101e+02, 2.6600000e+00],
#        [3.9818000e+01, 3.0400000e+00],
#        [1.8354500e+01, 2.9800000e+00],
#        [5.7357060e+02, 1.6100000e+00],
#        [6.4305000e+01, 2.1900000e+00],
#        [3.0243500e+01, 6.8400000e+00],
#        [5.8169000e+02, 1.5500000e+00],
#        [2.3396000e+01, 6.2700000e+00],
#        [1.9997000e+01, 6.0000000e+00],
#        [8.5110500e+01, 4.3300000e+00],
#        [5.5785716e+02, 1.5200000e+00],
#        [2.5073837e+02, 2.4300000e+00],
#        [2.6330000e+01, 5.4600000e+00],
#        [4.1592970e+02, 1.9900000e+00],
# ...

# %%
print('r2 score:',r2_score(y_test,pred_rfr))
print('mean_squared_error:', mean_squared_error(y_test,pred_rfr))
print('root mean_squared_error:',np.sqrt(mean_squared_error(y_test,pred_rfr)))
# Out:
# r2 score: 0.8692209370404917
# mean_squared_error: 19567.08042423845
# root mean_squared_error: 139.88238067833436

# %%
from sklearn.neighbors import KNeighborsRegressor
knn=KNeighborsRegressor()
knn.fit(x_train,y_train)
pred_knn=knn.predict(x_test)
pred_knn
# Out:
# array([[1.286000e+03, 1.600000e+00],
#        [1.664000e+01, 4.200000e+00],
#        [7.344000e+01, 7.000000e+00],
#        [1.174000e+01, 5.400000e+00],
#        [9.795000e+01, 3.200000e+00],
#        [2.207000e+02, 3.000000e+00],
#        [2.873000e+02, 2.000000e+00],
#        [3.173000e+01, 6.800000e+00],
#        [2.768000e+01, 4.200000e+00],
#        [1.370000e+01, 4.000000e+00],
#        [1.733600e+02, 2.600000e+00],
#        [9.400000e+00, 3.000000e+00],
#        [2.490000e+01, 3.000000e+00],
#        [8.020000e+02, 1.000000e+00],
#        [1.562000e+02, 4.000000e+00],
#        [5.832000e+01, 7.000000e+00],
#        [8.135000e+02, 1.000000e+00],
#        [1.992000e+01, 4.600000e+00],
#        [1.561600e+02, 1.800000e+00],
#        [3.300000e+01, 3.000000e+00],
#        [5.504040e+02, 1.400000e+00],
#        [3.381600e+02, 2.200000e+00],
#        [3.256000e+01, 7.000000e+00],
#        [2.028000e+02, 2.400000e+00],
#        [2.504000e+01, 3.000000e+00],
# ...

# %%
print('r2 score:',r2_score(y_test,pred_knn))
print('mean_squared_error:', mean_squared_error(y_test,pred_knn))
print('root mean_squared_error:',np.sqrt(mean_squared_error(y_test,pred_knn)))
# Out:
# r2 score: 0.5727390768344206
# mean_squared_error: 27718.620808144206
# root mean_squared_error: 166.48910116924833

# %%
from sklearn.linear_model import Lasso
ls=Lasso()
ls.fit(x_train,y_train)
pred_ls=ls.predict(x_test)
pred_ls
# Out:
# array([[ 1.29874336e+03,  1.78525759e+00],
#        [ 2.45043368e+01,  4.78190878e+00],
#        [ 5.94103437e+01,  4.99405635e+00],
#        [ 5.94373897e+01,  4.28529060e+00],
#        [-2.55225921e+02,  2.74374329e+00],
#        [ 4.37072730e+02,  2.26048955e+00],
#        [ 4.85348473e+02,  2.25418890e+00],
#        [ 2.73047720e+01,  3.92849696e+00],
#        [ 6.68175494e+01,  4.63244117e+00],
#        [ 5.46476095e+01,  4.22743217e+00],
#        [ 3.54140582e+02,  2.32937489e+00],
#        [ 4.85757969e+00,  2.53159044e+00],
#        [ 4.53077726e+00,  2.53941413e+00],
#        [ 7.87610215e+02,  2.10660732e+00],
#        [ 5.23001049e+01,  3.66813403e+00],
#        [ 5.94475282e+01,  4.99405635e+00],
#        [ 8.32647055e+02,  2.07937507e+00],
#        [ 4.98177843e+01,  3.78385089e+00],
#        [ 3.04593478e+01,  3.87546007e+00],
#        [-1.22238532e+02,  2.60538388e+00],
#        [ 7.51798410e+02,  2.11987768e+00],
#        [ 4.81932137e+02,  2.25277554e+00],
# ...

# %%
print('r2 score:',r2_score(y_test,pred_ls))
print('mean_squared_error:', mean_squared_error(y_test,pred_ls))
print('root mean_squared_error:',np.sqrt(mean_squared_error(y_test,pred_ls)))
# Out:
# r2 score: 0.5127524418941998
# mean_squared_error: 28218.433518051184
# root mean_squared_error: 167.98343227250473

# %%
from sklearn.linear_model import Ridge
rdg=Ridge()
rdg.fit(x_train,y_train)
pred_rdg=rdg.predict(x_test)
pred_rdg
# Out:
# array([[ 1.30555553e+03,  1.06464445e+00],
#        [ 2.01866980e+01,  4.49557556e+00],
#        [ 5.38667307e+01,  7.35127839e+00],
#        [ 6.32008631e+01,  5.69852481e+00],
#        [-1.85097650e+02,  2.82658045e+00],
#        [ 4.51183918e+02,  2.87999796e+00],
#        [ 4.78023419e+02,  2.85494985e+00],
#        [ 3.04944614e+01,  6.87893970e+00],
#        [ 8.69591983e+01,  5.91932875e+00],
#        [ 6.68558106e+01, -2.96974386e-01],
#        [ 3.54750449e+02,  3.05920563e+00],
#        [-3.16234710e+00,  3.07717989e+00],
#        [ 6.06398509e+00,  2.99207113e+00],
#        [ 8.09343795e+02,  1.08365864e+00],
#        [ 4.85391943e+01,  3.70898245e+00],
#        [ 5.40324434e+01,  7.04139311e+00],
#        [ 8.58358667e+02,  1.14025121e+00],
#        [ 3.79335207e+01,  4.37043932e+00],
#        [ 3.81247151e+01,  8.27457443e+00],
#        [-1.93820156e+02,  3.28427290e+00],
#        [ 7.34577691e+02,  1.06393336e+00],
#        [ 4.76112304e+02,  2.80169570e+00],
# ...

# %%
print('r2 score:',r2_score(y_test,pred_rdg))
print('mean_squared_error:', mean_squared_error(y_test,pred_rdg))
print('root mean_squared_error:',np.sqrt(mean_squared_error(y_test,pred_rdg)))
# Out:
# r2 score: 0.7849167790102668
# mean_squared_error: 27375.813410369894
# root mean_squared_error: 165.45637917702024

# %%
from sklearn.tree import DecisionTreeRegressor
dtr=DecisionTreeRegressor()
dtr.fit(x_train,y_train)
pred_dtr=dtr.predict(x_test)
pred_dtr
# Out:
# array([[1.20000e+03, 1.00000e+00],
#        [5.00000e+00, 6.00000e+00],
#        [5.10000e+01, 7.00000e+00],
#        [5.07000e+01, 1.00000e+00],
#        [5.20000e+02, 3.00000e+00],
#        [3.15000e+02, 3.00000e+00],
#        [4.31586e+02, 2.00000e+00],
#        [2.00000e+01, 6.00000e+00],
#        [5.04000e+01, 7.00000e+00],
#        [2.40000e+01, 0.00000e+00],
#        [2.90000e+02, 3.00000e+00],
#        [3.00000e+01, 3.00000e+00],
#        [2.10000e+01, 3.00000e+00],
#        [6.00000e+02, 1.00000e+00],
#        [5.00000e+01, 1.00000e+00],
#        [1.05000e+01, 7.00000e+00],
#        [6.10000e+02, 1.00000e+00],
#        [8.40000e+00, 7.00000e+00],
#        [2.00000e+01, 6.00000e+00],
#        [5.00000e+01, 3.00000e+00],
#        [6.00000e+02, 1.00000e+00],
#        [1.86000e+02, 3.00000e+00],
#        [2.55000e+01, 7.00000e+00],
#        [1.00000e+02, 1.00000e+00],
#        [2.04000e+01, 3.00000e+00],
#        [1.05000e+03, 1.00000e+00],
#        [1.50000e+01, 1.00000e+00],
# ...

# %%
print('r2 score:',r2_score(y_test,pred_dtr))
print('mean_squared_error:', mean_squared_error(y_test,pred_dtr))
print('root mean_squared_error:',np.sqrt(mean_squared_error(y_test,pred_dtr)))
# Out:
# r2 score: 0.6881213565129021
# mean_squared_error: 29027.964082043105
# root mean_squared_error: 170.37594924766555

# %%
from sklearn.ensemble import ExtraTreesRegressor
etr=ExtraTreesRegressor()
etr.fit(x_train,y_train)
pred_etr=etr.predict(x_test)
pred_etr
# Out:
# array([[1.5086000e+03, 1.1800000e+00],
#        [6.0360000e+00, 6.0000000e+00],
#        [7.7507000e+01, 7.0000000e+00],
#        [4.4469500e+01, 6.5500000e+00],
#        [7.4845662e+02, 2.1400000e+00],
#        [3.1743720e+02, 2.5700000e+00],
#        [3.5479342e+02, 2.1600000e+00],
#        [9.4340000e+00, 6.0000000e+00],
#        [1.6592500e+01, 6.8600000e+00],
#        [3.4110800e+01, 4.1000000e-01],
#        [1.6502880e+02, 2.7500000e+00],
#        [4.1175000e+01, 3.0000000e+00],
#        [1.4789000e+01, 3.0000000e+00],
#        [7.5551900e+02, 1.2700000e+00],
#        [4.2088000e+01, 1.3500000e+00],
#        [3.3863500e+01, 7.0000000e+00],
#        [6.1062500e+02, 1.5500000e+00],
#        [1.6386000e+01, 6.8500000e+00],
#        [3.2091000e+01, 5.8300000e+00],
#        [1.1352000e+02, 3.7000000e+00],
#        [6.1849906e+02, 1.3700000e+00],
#        [2.6419120e+02, 2.4300000e+00],
#        [2.9939000e+01, 6.4300000e+00],
#        [5.2669506e+02, 1.6100000e+00],
# ...

# %%
print('r2 score:',r2_score(y_test,pred_etr))
print('mean_squared_error:', mean_squared_error(y_test,pred_etr))
print('root mean_squared_error:',np.sqrt(mean_squared_error(y_test,pred_etr)))
# Out:
# r2 score: 0.891740256020721
# mean_squared_error: 18709.632693571763
# root mean_squared_error: 136.78315939314956

# %% [markdown]
# From the above model fitting and performance score, we can say that, ExtraTreeRegressor is the best fitting and best performing models,which is giving a performance score as 89.11.

# %%
from sklearn.model_selection import cross_val_score

# %%
score= cross_val_score(lr,x,y,cv=5,scoring='r2')
print(score)
print(score.mean())
print('Difference between r2 score and cross validation score is-',(r2_score(pred_lr,y_test)) - (score.mean()*100))
# Out:
# [0.78371408 0.75974818 0.72029738 0.74916924 0.80712338]
# 0.7640104502497069
# Difference between r2 score and cross validation score is- -75.6899503803411

# %%
score1= cross_val_score(knn,x,y,cv=5,scoring='r2')
print(score1)
print(score1.mean())
print('Difference between r2 score and cross validation score is-',(r2_score(pred_rfr,y_test)) - (score.mean()*100))
# Out:
# [0.53273683 0.51211958 0.42939209 0.44723282 0.51423108]
# 0.4871424824868814
# Difference between r2 score and cross validation score is- -75.58177163335174

# %%
score2= cross_val_score(knn,x,y,cv=5,scoring='r2')
print(score2)
print(score2.mean())
print('Difference between r2 score and cross validation score is-',(r2_score(pred_knn,y_test)) - (score.mean()*100))
# Out:
# [0.53273683 0.51211958 0.42939209 0.44723282 0.51423108]
# 0.4871424824868814
# Difference between r2 score and cross validation score is- -76.17814533437826

# %%
score4= cross_val_score(ls,x,y,cv=5,scoring='r2')
print(score4)
print(score4.mean())
print('Difference between r2 score and cross validation score is-',(r2_score(pred_ls,y_test)) - (score.mean()*100))
# Out:
# [0.50187517 0.50710333 0.43390512 0.46597258 0.57894498]
# 0.49756023724406084
# Difference between r2 score and cross validation score is- -77.0745558462856

# %%
score5= cross_val_score(rdg,x,y,cv=5,scoring='r2')
print(score5)
print(score5.mean())
print('Difference between r2 score and cross validation score is-',(r2_score(pred_rdg,y_test)) - (score.mean()*100))
# Out:
# [0.78489086 0.75733482 0.71923267 0.74675897 0.8136878 ]
# 0.7643810248443171
# Difference between r2 score and cross validation score is- -75.69705218888379

# %%
score6= cross_val_score(dtr,x,y,cv=5,scoring='r2')
print(score6)
print(score6.mean())
print('Difference between r2 score and cross validation score is-',(r2_score(pred_dtr,y_test)) - (score.mean()*100))
# Out:
# [0.4548     0.63403896 0.5873078  0.73888758 0.59900032]
# 0.602806932925435
# Difference between r2 score and cross validation score is- -75.76421772357855

# %%
score8= cross_val_score(etr,x,y,cv=5,scoring='r2')
print(score8)
print(score8.mean())
print('Difference between r2 score and cross validation score is-',(r2_score(pred_etr,y_test)) - (score.mean()*100))
# Out:
# [0.89870589 0.90391178 0.81814323 0.89477252 0.8906649 ]
# 0.8812396648427109
# Difference between r2 score and cross validation score is- -75.55208424702201

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    'n_estimators': [10,50,100],
    'criterion': ['mse', 'mae'],
    'max_depth': [2,8,16,32,50],
    #'oob_score': [True, False],
    'max_features': ['auto','sqrt','log2'],    
    'bootstrap': [True, False],
    'warm_start': [True, False],
}

# %%
from sklearn.ensemble import ExtraTreesRegressor
model = ExtraTreesRegressor ()

# %%
gcv = GridSearchCV(model,param_grid,cv=5,n_jobs=-1).fit(x_train,y_train)

# %%
model.fit(x_train,y_train)
pred=model.predict(x_test)
print('r2 score',r2_score(y_test,pred_etr))
print('mean squared error', mean_squared_error(y_test,pred_etr))
print('root mean squared error',np.sqrt(mean_squared_error(y_test,pred_etr)))
# Out:
# r2 score 0.891740256020721
# mean squared error 18709.632693571763
# root mean squared error 136.78315939314956

# %%
import pickle
filename='Global_power_plant_Prediction.pkl'
pickle.dump(model,open('Global_power_plant_Prediction.pkl','wb'))

# %%
loaded_model=pickle.load(open('Global_power_plant_Prediction.pkl','rb'))
result=loaded_model.score(x_test,y_test)
print(result*100)
# Out:
# 88.70116865258295

# %%
conclusion=pd.DataFrame([loaded_model.predict(x_test)[:],(y_test)[0:1]],index=['Predicted','Original'])
conclusion
# Out:
#                                                            0
# Predicted  [[1476.2, 1.12], [7.400000000000001, 6.0], [88...
# Original        capacity_mw  primary_fuel
# 623       1720....

# %%
def pred_etr(p):
    p=p.reshape(1,-1)
    pred=etr.predict(p)
    print('Response type',pred)

# %%
p=np.array([1.696859,2.122232,3,1,2004.000000,280,2.802039,3.870877,2,2019.000000,2.042177,2.114145,2.125655,2.058533,8.555526,0])
pred_etr(p)
# Out:
# Response type [[135.   2.]]
