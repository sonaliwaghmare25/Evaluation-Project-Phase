# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r"C:\Users\Sonali\Desktop\Flip Robo internship\Evaluation project phase\Datasets\First phase\baseball.csv")
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
df.tail()
# Out:
#      W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 25  92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26  84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27  79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28  74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29  68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV   E
# 25   21  47  75
# 26   18  41  78
# 27   12  44  86
# 28    6  41  92
# 29    4  36  95

# %%
df.sample()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO  SB   RA   ER  ERA  CG  SHO  \
# 5  93  891  5509  1480  308  17  232  570  1151  88  670  609  3.8   7   10
#
#    SV   E
# 5  34  88

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# The above heatmap clearly shows that there are no null values present in the data.

# %%
df.nunique()
# Out:
# W      24
# R      28
# AB     29
# H      29
# 2B     22
# 3B     23
# HR     27
# BB     29
# SO     29
# SB     27
# RA     30
# ER     30
# ERA    30
# CG      9
# SHO    12
# SV     20
# E      21
# dtype: int64

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# The above description shows that, the mean is larger than mode in some features and less in some features, so we have to check for the exact skewness present in the data.
#
# We can also see that, there is huge difference between 75% and max values, which shows the presence of outliers in the data.
#
# The above data shows the values of count, min, standard deviation and 25% as well.

# %%
sns.heatmap(df.describe(),annot=True, linewidth=0.5, linecolor='black', cmap='Spectral')
# Out:
# <AxesSubplot:>

# %%
df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
sns.distplot(df['R'],df['W'],'bins'==20)
# Out:
# <AxesSubplot:xlabel='R', ylabel='Density'>

# %%
sns.distplot(df['AB'],df['W'],'bins'==20)
# Out:
# <AxesSubplot:xlabel='AB', ylabel='Density'>

# %%
sns.distplot(df['H'],df['W'],'bins'==20)
# Out:
# <AxesSubplot:xlabel='H', ylabel='Density'>

# %%
sns.distplot(df['2B'],df['W'],'bins'==20)
# Out:
# <AxesSubplot:xlabel='2B', ylabel='Density'>

# %%
sns.distplot(df['3B'],df['W'],'bins'==20)
# Out:
# <AxesSubplot:xlabel='3B', ylabel='Density'>

# %%
sns.distplot(df['HR'],df['W'],'bins'==20)
# Out:
# <AxesSubplot:xlabel='HR', ylabel='Density'>

# %%
sns.distplot(df['BB'],df['W'],'bins'==20)
# Out:
# <AxesSubplot:xlabel='BB', ylabel='Density'>

# %%
sns.distplot(df['SO'],df['W'],'bins'==20)
# Out:
# <AxesSubplot:xlabel='SO', ylabel='Density'>

# %%
sns.distplot(df['SB'],df['W'],'bins'==20)
# Out:
# <AxesSubplot:xlabel='SB', ylabel='Density'>

# %%
sns.distplot(df['RA'],df['W'],'bins'==20)
# Out:
# <AxesSubplot:xlabel='RA', ylabel='Density'>

# %%
sns.distplot(df['ERA'],df['W'],'bins'==20)
# Out:
# <AxesSubplot:xlabel='ERA', ylabel='Density'>

# %%
sns.distplot(df['CG'],df['W'],'bins'==20)
# Out:
# <AxesSubplot:xlabel='CG', ylabel='Density'>

# %%
sns.distplot(df['SHO'],df['W'],'bins'==20)
# Out:
# <AxesSubplot:xlabel='SHO', ylabel='Density'>

# %%
sns.distplot(df['SV'],df['W'],'bins'==20)
# Out:
# <AxesSubplot:xlabel='SV', ylabel='Density'>

# %%
sns.distplot(df['E'],df['W'],'bins'==20)
# Out:
# <AxesSubplot:xlabel='E', ylabel='Density'>

# %% [markdown]
# The above distplots shows the presence of skewness in some features.

# %%
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %%
df['R']=np.cbrt(df['R'])

# %%
df.skew()
# Out:
# W      0.047089
# R      0.892970
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %% [markdown]
# Now, we will proceed further to check the presence of outliers.

# %%
df.boxplot()
# Out:
# <AxesSubplot:>

# %%
df['R'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['W'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['AB'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['H'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['2B'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['3B'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['HR'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['BB'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['SO'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['SB'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['RA'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['ER'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['ERA'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['CG'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['SHO'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['SV'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['E'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# From the above boxplots, we can see that very few features are having outliers.

# %%
from scipy.stats import zscore
outliers=df[['W','R','AB','H','2B','3B','HR','BB','SO','SB','RA','ER','ERA','CG','SHO','SV','E']]
z=np.abs(zscore(outliers))
z
# Out:
#            W         R        AB         H        2B        3B        HR  \
# 0   1.365409  0.650959  0.847731  1.663685  1.420173  1.041193  0.787299
# 1   0.197838  0.164710  0.711094  0.970681  0.127403  1.235809  0.243967
# 2   0.003243  0.316685  1.115233  0.151891  1.588795  0.223808  0.723377
# 3   0.483244  1.186544  0.241522  0.401088  0.828122  0.418423  0.883181
# 4   0.677839  0.041117  1.280738  1.984081  0.801892  1.722347  0.403770
# 5   1.170814  3.317778  0.104884  1.361089  1.869832  1.391501  2.185047
# 6   0.587028  1.324315  0.732263  0.116292  0.153633  1.196885  1.545833
# 7   0.003243  0.461454  0.451289  0.596886  1.615025  1.099578  1.705636
# 8   0.094054  0.774111  0.451289  0.365489  0.183611  0.068115  0.107601
# 9   0.288649  1.057861  1.785913  1.628086  1.082929  0.165423  0.084163
# 10  0.684326  1.108108  0.076017  0.275303  0.239818  0.068115  0.267405
# 11  0.489731  0.736464  0.826562  0.721484  0.183611  0.515731  2.121125
# ...

# %%
np.where(z>3)
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))

# %%
z.iloc[5,1]
# Out:
# 3.3177775022571434

# %%
df1=df[(z<3).all(axis=1)]
df1
# Out:
#       W         R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  \
# 0    95  8.979377  5575  1497  300  42  139  383   973  104  641  601  3.73
# 1    83  8.862095  5467  1349  277  44  156  439  1264   70  700  653  4.07
# 2    81  8.745985  5439  1395  303  29  141  533  1157   86  640  584  3.67
# 3    76  8.536178  5533  1381  260  27  136  404  1231   68  701  643  3.98
# 4    74  8.832285  5605  1515  289  49  151  455  1259   83  803  746  4.64
# 6    87  9.141787  5567  1397  272  19  212  554  1227   63  698  652  4.03
# 7    81  8.933669  5485  1370  246  20  217  418  1331   44  693  646  4.05
# 8    80  8.635655  5485  1383  278  32  167  436  1310   87  642  604  3.74
# 9    78  9.077520  5640  1495  294  33  161  478  1148   71  753  694  4.31
# 10   88  9.089639  5511  1419  279  32  172  503  1233  101  733  680  4.24
# 11   86  9.000000  5459  1363  278  26  230  486  1392  121  618  572  3.57
# ...

# %%
print('Old data shape',df.shape)
print('New data shape',df1.shape)
# Out:
# Old data shape (30, 17)
# New data shape (29, 17)

# %%
print('Data loss percentage',((df.shape[0]-df1.shape[0])/df.shape[0])*100)
# Out:
# Data loss percentage 3.3333333333333335

# %% [markdown]
# As the above data loss is not affordable, we will check the presence of outliers with the help of IQR method.

# %%
Q1=df1.quantile(.25)
Q3=df1.quantile(.75)
IQR=Q3-Q1
IQR
# Out:
# W       13.000000
# R        0.271278
# AB     108.000000
# H       57.000000
# 2B      26.000000
# 3B      13.000000
# HR      37.000000
# BB      70.000000
# SO     153.000000
# SB      28.000000
# RA      98.000000
# ER      96.000000
# ERA      0.570000
# CG       4.000000
# SHO      4.000000
# SV       9.000000
# E       11.000000
# dtype: float64

# %%
df1_new=df1[(z<3).all(axis=1)]
df1_new
# Out:
#       W         R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  \
# 0    95  8.979377  5575  1497  300  42  139  383   973  104  641  601  3.73
# 1    83  8.862095  5467  1349  277  44  156  439  1264   70  700  653  4.07
# 2    81  8.745985  5439  1395  303  29  141  533  1157   86  640  584  3.67
# 3    76  8.536178  5533  1381  260  27  136  404  1231   68  701  643  3.98
# 4    74  8.832285  5605  1515  289  49  151  455  1259   83  803  746  4.64
# 6    87  9.141787  5567  1397  272  19  212  554  1227   63  698  652  4.03
# 7    81  8.933669  5485  1370  246  20  217  418  1331   44  693  646  4.05
# 8    80  8.635655  5485  1383  278  32  167  436  1310   87  642  604  3.74
# 9    78  9.077520  5640  1495  294  33  161  478  1148   71  753  694  4.31
# 10   88  9.089639  5511  1419  279  32  172  503  1233  101  733  680  4.24
# 11   86  9.000000  5459  1363  278  26  230  486  1392  121  618  572  3.57
# ...

# %%
print('Old data shape',df1.shape)
print('New data shape',df1_new.shape)
# Out:
# Old data shape (29, 17)
# New data shape (29, 17)

# %% [markdown]
# We can see from IQR method, that there are no outliers present in the data now.

# %%
plt.figure(figsize=(25,20))
p=1
for i in outliers:
    if p<=18:
        ax=plt.subplot(5,4,p)
        sns.distplot(df[i],color='r')
        plt.xlabel(i,fontsize=15)
    p+=1
plt.show()

# %% [markdown]
# Here, we have cleared all the outliers from the data using zscore and IQR method. We can see from the above plots, all the features are showing almost normal distribution.

# %%
plt.figure(figsize=(20,16))
plt.subplot(6,4,3)
sns.histplot(df['W'],kde=True)
plt.show()

# %%
df1_new.skew()
# Out:
# W      0.119013
# R     -0.329729
# AB     0.169573
# H      0.783772
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG     0.854980
# SHO    0.526943
# SV     0.627480
# E      0.840271
# dtype: float64

# %%
sns.distplot(df1_new['W'],color='b',kde_kws={'shade':True},hist=False)
# Out:
# <AxesSubplot:xlabel='W', ylabel='Density'>

# %%
df1_new
# Out:
#       W         R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  \
# 0    95  8.979377  5575  1497  300  42  139  383   973  104  641  601  3.73
# 1    83  8.862095  5467  1349  277  44  156  439  1264   70  700  653  4.07
# 2    81  8.745985  5439  1395  303  29  141  533  1157   86  640  584  3.67
# 3    76  8.536178  5533  1381  260  27  136  404  1231   68  701  643  3.98
# 4    74  8.832285  5605  1515  289  49  151  455  1259   83  803  746  4.64
# 6    87  9.141787  5567  1397  272  19  212  554  1227   63  698  652  4.03
# 7    81  8.933669  5485  1370  246  20  217  418  1331   44  693  646  4.05
# 8    80  8.635655  5485  1383  278  32  167  436  1310   87  642  604  3.74
# 9    78  9.077520  5640  1495  294  33  161  478  1148   71  753  694  4.31
# 10   88  9.089639  5511  1419  279  32  172  503  1233  101  733  680  4.24
# 11   86  9.000000  5459  1363  278  26  230  486  1392  121  618  572  3.57
# ...

# %%
x=df1_new.iloc[:,1:17]
x
# Out:
#            R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0   8.979377  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1   8.862095  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2   8.745985  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3   8.536178  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4   8.832285  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 6   9.141787  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7   8.933669  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8   8.635655  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9   9.077520  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10  9.089639  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11  9.000000  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# ...

# %%
y=df1_new.iloc[:,0]
y
# Out:
# 0      95
# 1      83
# 2      81
# 3      76
# 4      74
# 6      87
# 7      81
# 8      80
# 9      78
# 10     88
# 11     86
# 12     85
# 13     76
# 14     68
# 15    100
# 16     98
# 17     97
# 18     68
# 19     64
# 20     90
# 21     83
# 22     71
# 23     67
# 24     63
# 25     92
# 26     84
# 27     79
# 28     74
# 29     68
# Name: W, dtype: int64

# %%
print(x.shape)
print(y.shape)
# Out:
# (29, 16)
# (29,)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif['VIF Values']=[variance_inflation_factor(x.values,i)for i in range(len(x.columns))]
vif['Features']=x.columns
vif
# Out:
#       VIF Values Features
# 0   14421.250185        R
# 1   10303.136148       AB
# 2    3459.454560        H
# 3     836.754899       2B
# 4      35.314185       3B
# 5     252.734949       HR
# 6     255.256949       BB
# 7     386.640536       SO
# 8      28.330480       SB
# 9   18118.838020       RA
# 10  70798.932389       ER
# 11  37498.673633      ERA
# 12      5.780302       CG
# 13     30.064376      SHO
# 14    116.278712       SV
# 15     84.593103        E

# %% [markdown]
# From the above VIF values, we can see that ER,ERA and AB,H are highly corelative with each other, so we can drop those columns.

# %%
df1_new.drop(['ER','ERA','AB','H'],axis=1,inplace=True)

# %%
df1_new
# Out:
#       W         R   2B  3B   HR   BB    SO   SB   RA  CG  SHO  SV    E
# 0    95  8.979377  300  42  139  383   973  104  641   2    8  56   88
# 1    83  8.862095  277  44  156  439  1264   70  700   2   12  45   86
# 2    81  8.745985  303  29  141  533  1157   86  640  11   10  38   79
# 3    76  8.536178  260  27  136  404  1231   68  701   7    9  37  101
# 4    74  8.832285  289  49  151  455  1259   83  803   7   12  35   86
# 6    87  9.141787  272  19  212  554  1227   63  698   3    4  48   93
# 7    81  8.933669  246  20  217  418  1331   44  693   0   10  43   77
# 8    80  8.635655  278  32  167  436  1310   87  642   1   12  60   95
# 9    78  9.077520  294  33  161  478  1148   71  753   3   10  40   97
# 10   88  9.089639  279  32  172  503  1233  101  733   5    9  45  119
# 11   86  9.000000  278  26  230  486  1392  121  618   5   13  39   85
# 12   85  8.710983  243  21  176  435  1150   52  675   2   12  46   93
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=42)

# %%
x_train.shape
# Out:
# (20, 16)

# %%
x_test.shape
# Out:
# (9, 16)

# %%
y_train.shape
# Out:
# (20,)

# %%
y_test.shape
# Out:
# (9,)

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
pred=lr.predict(x_test)
pred
# Out:
# array([77.06563565, 77.62912816, 76.562687  , 58.68345172, 81.45106258,
#        78.92669019, 75.84757533, 98.78027935, 85.15837218])

# %%
print(r2_score(pred,y_test))
print(mean_absolute_error(pred,y_test))
print(mean_squared_error(pred,y_test))
print(np.sqrt(mean_squared_error(pred,y_test)))
# Out:
# 0.2821700232066163
# 6.5140380020603805
# 69.34002446260506
# 8.327065777487594

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=pred,y=y_test,color='b')
plt.plot(pred,pred,color='b')
plt.xlabel('actual',fontsize=12)
plt.ylabel('linear regression',fontsize=12)
plt.title('Linear Regression Model',fontsize=15)
plt.show()

# %%
from sklearn.ensemble import RandomForestRegressor
rfr=RandomForestRegressor()
rfr.fit(x_train,y_train)
pred_rfr=rfr.predict(x_test)
pred_rfr
# Out:
# array([73.93, 91.64, 72.  , 70.57, 71.89, 71.07, 79.54, 84.68, 75.48])

# %%
print(r2_score(pred_rfr,y_test))
print(mean_absolute_error(pred_rfr,y_test))
print(mean_squared_error(pred_rfr,y_test))
print(np.sqrt(mean_squared_error(pred_rfr,y_test)))
# Out:
# -0.3695271178381918
# 6.49111111111111
# 63.69564444444446
# 7.980955108534595

# %%
from sklearn.neighbors import KNeighborsRegressor
knn=KNeighborsRegressor()
knn.fit(x_train,y_train)
pred_knn=knn.predict(x_test)
pred_knn
# Out:
# array([77.6, 86.2, 75.2, 78.6, 75.4, 75.6, 79.2, 78.8, 81.4])

# %%
print(r2_score(pred_knn,y_test))
print(mean_absolute_error(pred_knn,y_test))
print(mean_squared_error(pred_knn,y_test))
print(np.sqrt(mean_squared_error(pred_knn,y_test)))
# Out:
# -6.781914893617016
# 7.622222222222222
# 84.52888888888889
# 9.193959369547425

# %%
from sklearn.ensemble import GradientBoostingRegressor
gbr=GradientBoostingRegressor()
gbr.fit(x_train,y_train)
pred_gbr=gbr.predict(x_test)
pred_gbr
# Out:
# array([66.34244476, 92.79860213, 67.09119255, 64.52978392, 68.78742342,
#        69.13047645, 80.38389531, 85.48757995, 68.57021861])

# %%
print(r2_score(pred_gbr,y_test))
print(mean_absolute_error(pred_gbr,y_test))
print(mean_squared_error(pred_gbr,y_test))
print(np.sqrt(mean_squared_error(pred_gbr,y_test)))
# Out:
# -0.11028756341196178
# 8.960685945881435
# 98.89035181257479
# 9.944362815815541

# %%
from sklearn.linear_model import Lasso
lasso=Lasso()
lasso.fit(x_train,y_train)
pred_lasso=lasso.predict(x_test)
pred_lasso
# Out:
# array([72.58442239, 85.51079263, 78.55973038, 68.06892283, 79.86915248,
#        75.6307128 , 73.03038574, 90.53537008, 79.09018695])

# %%
print(r2_score(pred_lasso,y_test))
print(mean_absolute_error(pred_lasso,y_test))
print(mean_squared_error(pred_lasso,y_test))
print(np.sqrt(mean_squared_error(pred_lasso,y_test)))
# Out:
# 0.14457686696574834
# 4.150786718502952
# 35.80634207574842
# 5.983840077721698

# %%
from sklearn.linear_model import Ridge
rdg=Ridge()
rdg.fit(x_train,y_train)
pred_rdg=rdg.predict(x_test)
pred_rdg
# Out:
# array([77.28300175, 84.63078383, 77.72926924, 69.99632811, 81.01781962,
#        75.97268968, 73.70784952, 94.63736723, 80.83134715])

# %%
print(r2_score(pred_rdg,y_test))
print(mean_absolute_error(pred_rdg,y_test))
print(mean_squared_error(pred_rdg,y_test))
print(np.sqrt(mean_squared_error(pred_rdg,y_test)))
# Out:
# 0.15738554826240048
# 4.480530519018043
# 37.81390848651293
# 6.149301463297513

# %%
from sklearn.tree import DecisionTreeRegressor
dtr=DecisionTreeRegressor()
dtr.fit(x_train,y_train)
pred_dtr=dtr.predict(x_test)
pred_dtr
# Out:
# array([63., 92., 64., 64., 68., 68., 80., 86., 68.])

# %%
print(r2_score(pred_dtr,y_test))
print(mean_absolute_error(pred_dtr,y_test))
print(mean_squared_error(pred_dtr,y_test))
print(np.sqrt(mean_squared_error(pred_dtr,y_test)))
# Out:
# -0.18351968886728254
# 10.0
# 120.22222222222223
# 10.96458946893235

# %%
from sklearn.svm import SVR
svr=SVR()
svr.fit(x_train,y_train)
pred_svr=svr.predict(x_test)
pred_svr
# Out:
# array([81.98943197, 82.01300413, 81.98780678, 81.98349627, 81.97762984,
#        81.98638049, 81.98858762, 81.98869996, 81.98465524])

# %%
print(r2_score(pred_svr,y_test))
print(mean_absolute_error(pred_svr,y_test))
print(mean_squared_error(pred_svr,y_test))
print(np.sqrt(mean_squared_error(pred_svr,y_test)))
# Out:
# -1178915.260127188
# 8.991502570732553
# 99.97070791475382
# 9.998535288468698

# %%
from sklearn.ensemble import ExtraTreesRegressor
etr=ExtraTreesRegressor()
etr.fit(x_train,y_train)
pred_etr=etr.predict(x_test)
pred_etr
# Out:
# array([74.86, 92.26, 75.97, 70.81, 71.82, 71.81, 76.95, 82.99, 79.92])

# %%
print(r2_score(pred_etr,y_test))
print(mean_absolute_error(pred_etr,y_test))
print(mean_squared_error(pred_etr,y_test))
print(np.sqrt(mean_squared_error(pred_etr,y_test)))
# Out:
# -0.39065924353210324
# 5.632222222222223
# 57.61352222222224
# 7.59035718673517

# %% [markdown]
# From the above model fitting and performance score, we can say that,Linear Regression is the best fitting and best performing model, which is giving the performance score as 90%

# %%
from sklearn.model_selection import cross_val_score

# %%
score=cross_val_score(lr,x,y,cv=5,scoring='r2')
print(score)
print(score.mean())
print('Difference between r2 score and cross validation score -',(r2_score(y_test,pred)-(score.mean()*100)))
# Out:
# [ 0.77242963 -0.71624072  0.68398624 -0.34155599 -0.32306555]
# 0.01511072229381274
# Difference between r2 score and cross validation score - -1.21844527490659

# %%
score1=cross_val_score(rfr,x,y,cv=5,scoring='r2')
print(score1)
print(score1.mean())
print('Difference between r2 score and cross validation score -',(r2_score(y_test,pred)-(score1.mean()*100)))
# Out:
# [ 0.23042841 -5.42250395  0.49372012  0.48240934  0.9382273 ]
# -0.6555437554762197
# Difference between r2 score and cross validation score - 65.84700250209666

# %%
score2=cross_val_score(lr,x,y,cv=5,scoring='r2')
print(score2)
print(score2.mean())
print('Difference between r2 score and cross validation score -',(r2_score(y_test,pred)-(score2.mean()*100)))
# Out:
# [ 0.77242963 -0.71624072  0.68398624 -0.34155599 -0.32306555]
# 0.01511072229381274
# Difference between r2 score and cross validation score - -1.21844527490659

# %%
score3=cross_val_score(knn,x,y,cv=5,scoring='r2')
print(score3)
print(score3.mean())
print('Difference between r2 score and cross validation score -',(r2_score(y_test,pred)-(score3.mean()*100)))
# Out:
# [-0.68804545 -2.90684211  0.27223756 -0.1357377   0.60448113]
# -0.5707813150287713
# Difference between r2 score and cross validation score - 57.37075845735181

# %%
score4=cross_val_score(gbr,x,y,cv=5,scoring='r2')
print(score4)
print(score4.mean())
print('Difference between r2 score and cross validation score -',(r2_score(y_test,pred)-(score4.mean()*100)))
# Out:
# [-0.04669114 -9.11491177  0.45387482  0.59298167  0.80917356]
# -1.4611145724186028
# Difference between r2 score and cross validation score - 146.40408419633496

# %%
score5=cross_val_score(lasso,x,y,cv=5,scoring='r2')
print(score5)
print(score5.mean())
print('Difference between r2 score and cross validation score -',(r2_score(y_test,pred)-(score5.mean()*100)))
# Out:
# [ 0.36421213 -2.75312783  0.41146157  0.59776308  0.98412826]
# -0.07911255826452382
# Difference between r2 score and cross validation score - 8.203882780927065

# %%
score6=cross_val_score(rdg,x,y,cv=5,scoring='r2')
print(score6)
print(score6.mean())
print('Difference between r2 score and cross validation score -',(r2_score(y_test,pred)-(score6.mean()*100)))
# Out:
# [ 0.38007363 -2.47165113  0.3527635   0.72249744 -0.74590933]
# -0.35244517778303414
# Difference between r2 score and cross validation score - 35.537144732778096

# %%
score7=cross_val_score(dtr,x,y,cv=5,scoring='r2')
print(score7)
print(score7.mean())
print('Difference between r2 score and cross validation score -',(r2_score(y_test,pred)-(score7.mean()*100)))
# Out:
# [ -1.625      -10.61842105   0.32413216  -0.67868852  -0.39740566]
# -2.5990766150647806
# Difference between r2 score and cross validation score - 260.2002884609527

# %%
score8=cross_val_score(svr,x,y,cv=5,scoring='r2')
print(score8)
print(score8.mean())
print('Difference between r2 score and cross validation score -',(r2_score(y_test,pred)-(score8.mean()*100)))
# Out:
# [-0.14668236 -1.25778014 -0.06358373 -0.64215928 -0.03392726]
# -0.4288265540330384
# Difference between r2 score and cross validation score - 43.17528235777852

# %%
score9=cross_val_score(etr,x,y,cv=5,scoring='r2')
print(score9)
print(score9.mean())
print('Difference between r2 score and cross validation score -',(r2_score(y_test,pred)-(score9.mean()*100)))
# Out:
# [ 0.08735125 -4.769275    0.61393793  0.34164525  0.81445755]
# -0.5823766046019362
# Difference between r2 score and cross validation score - 58.5302874146683

# %%
from sklearn.model_selection import GridSearchCV

# %%
para={'fit_intercept':[True,False],
        'n_jobs':[None],'copy_X':[True,False],
       
        }
gscv=GridSearchCV(LinearRegression(),para,cv=5)
gscv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=LinearRegression(),
#              param_grid={'copy_X': [True, False],
#                          'fit_intercept': [True, False], 'n_jobs': [None]})

# %%
gscv.best_params_
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None}

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression ()

# %%
gcv = GridSearchCV(model,para,cv=5,n_jobs=-1).fit(x_train,y_train)

# %%
model.fit(x_train,y_train)
pred=model.predict(x_test)
print('r2 score',r2_score(y_test,pred))
print('mean squared error', mean_squared_error(y_test,pred))
print('root mean squared error',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# r2 score 0.2926269544746839
# mean squared error 69.34002446260506
# root mean squared error 8.327065777487594

# %%
import pickle
filename='Baseball win Prediction.pkl'
pickle.dump(model,open('Baseball win Prediction.pkl','wb'))

# %%
loaded_model=pickle.load(open('Baseball win Prediction.pkl','rb'))
result=loaded_model.score(x_test,y_test)
print(result*100)
# Out:
# 29.26269544746839

# %%
conclusion=pd.DataFrame([loaded_model.predict(x_test)[:],(y_test)[:]],index=['Predicted','Original'])
conclusion
# Out:
#                    0          1          2          3          4         5  \
# Predicted  77.065636  77.629128  76.562687  58.683452  81.451063  78.92669
# Original   74.000000  97.000000  76.000000  67.000000  78.000000  88.00000
#
#                    6          7          8
# Predicted  75.847575  98.780279  85.158372
# Original   71.000000  95.000000  79.000000
