# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import LabelEncoder

# %%
ds=pd.read_csv(r"C:\Users\Sonali\Desktop\Flip Robo internship\Evaluation project phase\Datasets\First phase\avocado.csv.zip")
ds
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
ds.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
ds.tail()
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046     4225  \
# 18244           7  2018-02-04          1.63      17074.83  2046.96  1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70  3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92  2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63  2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77  2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 18244    0.00    13498.67    13066.82      431.85          0.0  organic  2018
# 18245    0.00     9264.84     8940.04      324.80          0.0  organic  2018
# 18246  727.94     9394.11     9351.80       42.31          0.0  organic  2018
# 18247  727.01    10969.54    10919.54       50.00          0.0  organic  2018
# 18248  224.53    12014.15    11988.14       26.01          0.0  organic  2018
#
#                  region
# ...

# %%
ds.sample()
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046     4225  \
# 10224           6  2015-11-15          2.05       4981.33  1845.67  2977.95
#
#        4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 10224   0.0      157.71       43.33      114.38          0.0  organic  2015
#
#          region
# 10224  LasVegas

# %%
ds.dtypes
# Out:
# Unnamed: 0        int64
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %%
le=LabelEncoder()

# %%
ds['type']=le.fit_transform(ds['type'])

# %%
ds['year']=le.fit_transform(ds['year'])

# %%
ds['region']=le.fit_transform(ds['region'])

# %%
ds
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
ds.isnull().sum()
# Out:
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
sns.heatmap(ds.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# The above heatmap shows that there are no null values present in the data.

# %%
ds.nunique()
# Out:
# Unnamed: 0         53
# Date              169
# AveragePrice      259
# Total Volume    18237
# 4046            17702
# 4225            18103
# 4770            12071
# Total Bags      18097
# Small Bags      17321
# Large Bags      15082
# XLarge Bags      5588
# type                2
# year                4
# region             54
# dtype: int64

# %%
ds['Date']=le.fit_transform(ds['Date'])

# %%
ds
# Out:
#        Unnamed: 0  Date  AveragePrice  Total Volume     4046       4225  \
# 0               0    51          1.33      64236.62  1036.74   54454.85
# 1               1    50          1.35      54876.98   674.28   44638.81
# 2               2    49          0.93     118220.22   794.70  109149.67
# 3               3    48          1.08      78992.15  1132.00   71976.41
# 4               4    47          1.28      51039.60   941.48   43838.39
# ...           ...   ...           ...           ...      ...        ...
# 18244           7   161          1.63      17074.83  2046.96    1529.20
# 18245           8   160          1.71      13888.04  1191.70    3431.50
# 18246           9   159          1.87      13766.76  1191.92    2452.79
# 18247          10   158          1.93      16205.22  1527.63    2981.04
# 18248          11   157          1.62      17489.58  2894.77    2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags  type  year  \
# ...

# %%
ds.describe()
# Out:
#          Unnamed: 0          Date  AveragePrice  Total Volume          4046  \
# count  18249.000000  18249.000000  18249.000000  1.824900e+04  1.824900e+04
# mean      24.232232     83.997096      1.405978  8.506440e+05  2.930084e+05
# std       15.481045     48.787638      0.402677  3.453545e+06  1.264989e+06
# min        0.000000      0.000000      0.440000  8.456000e+01  0.000000e+00
# 25%       10.000000     42.000000      1.100000  1.083858e+04  8.540700e+02
# 50%       24.000000     84.000000      1.370000  1.073768e+05  8.645300e+03
# 75%       38.000000    126.000000      1.660000  4.329623e+05  1.110202e+05
# max       52.000000    168.000000      3.250000  6.250565e+07  2.274362e+07
#
#                4225          4770    Total Bags    Small Bags    Large Bags  \
# count  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04
# mean   2.951546e+05  2.283974e+04  2.396392e+05  1.821947e+05  5.433809e+04
# ...

# %% [markdown]
# From the above description we can see that, there is very small diffrence in mean and mode values, which shows the less skewness is present in the data.
#
# The diffrence between 75% and max is very large which means that the outliers are present in the data.
#
# We can also see the values of min, standard deviation, count and 25%.

# %%
sns.heatmap(ds.describe(),annot=True, linewidth=0.5, linecolor='black', cmap='Spectral')
# Out:
# <AxesSubplot:>

# %%
ds.corr()
# Out:
#               Unnamed: 0      Date  AveragePrice  Total Volume      4046  \
# Unnamed: 0      1.000000 -0.419926     -0.133008      0.014035  0.017628
# Date           -0.419926  1.000000      0.145514      0.009263 -0.005028
# AveragePrice   -0.133008  0.145514      1.000000     -0.192752 -0.208317
# Total Volume    0.014035  0.009263     -0.192752      1.000000  0.977863
# 4046            0.017628 -0.005028     -0.208317      0.977863  1.000000
# 4225            0.019829 -0.016895     -0.172928      0.974181  0.926110
# 4770            0.041752 -0.047517     -0.179446      0.872202  0.833389
# Total Bags     -0.002219  0.064688     -0.177088      0.963047  0.920057
# Small Bags      0.000347  0.056902     -0.174730      0.967238  0.925280
# Large Bags     -0.009196  0.081855     -0.172940      0.880640  0.838645
# XLarge Bags    -0.011546  0.077374     -0.117592      0.747157  0.699377
# type           -0.000288 -0.000060      0.615845     -0.232434 -0.225819
# ...

# %%
sns.heatmap(ds.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# The above heatmap shows the correlation of all the features with each other feature.

# %%
sns.histplot(ds['Unnamed: 0'])
# Out:
# <AxesSubplot:xlabel='Unnamed: 0', ylabel='Count'>

# %%
sns.distplot(ds['Unnamed: 0'],ds['AveragePrice'],'bins'==20)
# Out:
# <AxesSubplot:xlabel='Unnamed: 0', ylabel='Density'>

# %%
sns.distplot(ds['Unnamed: 0'],ds['region'],'bins'==20)
# Out:
# <AxesSubplot:xlabel='Unnamed: 0', ylabel='Density'>

# %%
sns.histplot(ds['Date'])
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Count'>

# %%
sns.distplot(ds['Date'],ds['AveragePrice'],'bins'==10)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Density'>

# %%
sns.distplot(ds['Date'],ds['region'],'bins'==10)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Density'>

# %%
sns.histplot(ds['AveragePrice'])
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='Count'>

# %%
sns.distplot(ds['AveragePrice'],ds['region'],'bins'==20)
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='Density'>

# %%
sns.histplot(ds['Total Volume'])
# Out:
# <AxesSubplot:xlabel='Total Volume', ylabel='Count'>

# %%
sns.distplot(ds['Total Volume'],ds['region'],'bins'==20)
# Out:
# <AxesSubplot:xlabel='Total Volume', ylabel='Density'>

# %%
sns.distplot(ds['AveragePrice'],ds['AveragePrice'],'bins'==20)
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='Density'>

# %%
sns.histplot(ds['4046'])
# Out:
# <AxesSubplot:xlabel='4046', ylabel='Count'>

# %%
sns.distplot(ds['4046'],ds['AveragePrice'],'bins'==20)
# Out:
# <AxesSubplot:xlabel='4046', ylabel='Density'>

# %%
sns.distplot(ds['4046'],ds['region'],'bins'==20)
# Out:
# <AxesSubplot:xlabel='4046', ylabel='Density'>

# %%
sns.histplot(ds['4225'])
# Out:
# <AxesSubplot:xlabel='4225', ylabel='Count'>

# %%
sns.distplot(ds['4225'],ds['region'],'bins'==20)
# Out:
# <AxesSubplot:xlabel='4225', ylabel='Density'>

# %%
sns.distplot(ds['4225'],ds['AveragePrice'],'bins'==20)
# Out:
# <AxesSubplot:xlabel='4225', ylabel='Density'>

# %%
sns.histplot(ds['4770'])
# Out:
# <AxesSubplot:xlabel='4770', ylabel='Count'>

# %%
sns.distplot(ds['4770'],ds['AveragePrice'],'bins'==20)
# Out:
# <AxesSubplot:xlabel='4770', ylabel='Density'>

# %%
sns.distplot(ds['4770'],ds['region'],'bins'==20)
# Out:
# <AxesSubplot:xlabel='4770', ylabel='Density'>

# %%
sns.histplot(ds['Total Bags'])
# Out:
# <AxesSubplot:xlabel='Total Bags', ylabel='Count'>

# %%
sns.distplot(ds['Total Bags'],ds['region'],'bins'==20)
# Out:
# <AxesSubplot:xlabel='Total Bags', ylabel='Density'>

# %%
sns.distplot(ds['Total Bags'],ds['AveragePrice'],'bins'==20)
# Out:
# <AxesSubplot:xlabel='Total Bags', ylabel='Density'>

# %%
sns.histplot(ds['Small Bags'])
# Out:
# <AxesSubplot:xlabel='Small Bags', ylabel='Count'>

# %%
sns.distplot(ds['Small Bags'],ds['AveragePrice'],'bins'==20)
# Out:
# <AxesSubplot:xlabel='Small Bags', ylabel='Density'>

# %%
sns.distplot(ds['Small Bags'],ds['region'],'bins'==20)
# Out:
# <AxesSubplot:xlabel='Small Bags', ylabel='Density'>

# %%
sns.histplot(ds['Large Bags'])
# Out:
# <AxesSubplot:xlabel='Large Bags', ylabel='Count'>

# %%
sns.distplot(ds['Large Bags'],ds['region'],'bins'==20)
# Out:
# <AxesSubplot:xlabel='Large Bags', ylabel='Density'>

# %%
sns.distplot(ds['Large Bags'],ds['AveragePrice'],'bins'==20)
# Out:
# <AxesSubplot:xlabel='Large Bags', ylabel='Density'>

# %%
sns.histplot(ds['XLarge Bags'])
# Out:
# <AxesSubplot:xlabel='XLarge Bags', ylabel='Count'>

# %%
sns.distplot(ds['XLarge Bags'],ds['AveragePrice'],'bins'==20)
# Out:
# <AxesSubplot:xlabel='XLarge Bags', ylabel='Density'>

# %%
sns.distplot(ds['XLarge Bags'],ds['region'],'bins'==20)
# Out:
# <AxesSubplot:xlabel='XLarge Bags', ylabel='Density'>

# %%
sns.histplot(ds['type'])
# Out:
# <AxesSubplot:xlabel='type', ylabel='Count'>

# %%
sns.distplot(ds['type'],ds['AveragePrice'],'bins'==20)
# Out:
# <AxesSubplot:xlabel='type', ylabel='Density'>

# %%
sns.distplot(ds['type'],ds['region'],'bins'==20)
# Out:
# <AxesSubplot:xlabel='type', ylabel='Density'>

# %%
sns.histplot(ds['year'])
# Out:
# <AxesSubplot:xlabel='year', ylabel='Count'>

# %%
sns.distplot(ds['year'],ds['AveragePrice'],'bins'==20)
# Out:
# <AxesSubplot:xlabel='year', ylabel='Density'>

# %%
sns.distplot(ds['year'],ds['region'],'bins'==20)
# Out:
# <AxesSubplot:xlabel='year', ylabel='Density'>

# %%
sns.histplot(ds['region'])
# Out:
# <AxesSubplot:xlabel='region', ylabel='Count'>

# %%
sns.distplot(ds['region'],ds['AveragePrice'],'bins'==20)
# Out:
# <AxesSubplot:xlabel='region', ylabel='Density'>

# %% [markdown]
# The above histplots and distplots shows the data didtribution and the presence of skewness for each feature.

# %%
ds.skew()
# Out:
# Unnamed: 0       0.108334
# Date             0.000117
# AveragePrice     0.580303
# Total Volume     9.007687
# 4046             8.648220
# 4225             8.942466
# 4770            10.159396
# Total Bags       9.756072
# Small Bags       9.540660
# Large Bags       9.796455
# XLarge Bags     13.139751
# type             0.000329
# year             0.215339
# region           0.000030
# dtype: float64

# %%
ds['Total Volume']=np.cbrt(ds['Total Volume'])

# %%
ds['4046']=np.cbrt(ds['4046'])

# %%
ds['4225']=np.cbrt(ds['4225'])

# %%
ds['4770']=np.cbrt(ds['4770'])

# %%
ds['Total Bags']=np.cbrt(ds['Total Bags'])

# %%
ds['Small Bags']=np.cbrt(ds['Small Bags'])

# %%
ds['Large Bags']=np.cbrt(ds['Large Bags'])

# %%
ds['XLarge Bags']=np.cbrt(ds['XLarge Bags'])

# %%
ds.skew()
# Out:
# Unnamed: 0      0.108334
# Date            0.000117
# AveragePrice    0.580303
# Total Volume    2.236143
# 4046            2.277861
# 4225            2.130378
# 4770            2.316048
# Total Bags      2.302176
# Small Bags      2.217682
# Large Bags      2.186514
# XLarge Bags     2.842255
# type            0.000329
# year            0.215339
# region          0.000030
# dtype: float64

# %%
ds['Total Volume']=np.sqrt(ds['Total Volume'])

# %%
ds['4046']=np.sqrt(ds['4046'])

# %%
ds['4225']=np.sqrt(ds['4225'])

# %%
ds['4770']=np.sqrt(ds['4770'])

# %%
ds['Total Bags']=np.cbrt(ds['Total Bags'])

# %%
ds['Small Bags']=np.sqrt(ds['Small Bags'])

# %%
ds['Large Bags']=np.sqrt(ds['Large Bags'])

# %%
ds['XLarge Bags']=np.cbrt(ds['XLarge Bags'])

# %%
ds.skew()
# Out:
# Unnamed: 0      0.108334
# Date            0.000117
# AveragePrice    0.580303
# Total Volume    0.950027
# 4046            0.850203
# 4225            0.717992
# 4770            0.605972
# Total Bags      0.473809
# Small Bags      0.690221
# Large Bags      0.316832
# XLarge Bags     1.023563
# type            0.000329
# year            0.215339
# region          0.000030
# dtype: float64

# %% [markdown]
# Now we will move forward for checking the presence of outliers.

# %%
ds.plot.box()
# Out:
# <AxesSubplot:>

# %%
ds['Unnamed: 0'].plot.box()
# Out:
# <AxesSubplot:>

# %%
ds['Date'].plot.box()
# Out:
# <AxesSubplot:>

# %%
ds['AveragePrice'].plot.box()
# Out:
# <AxesSubplot:>

# %%
ds['Total Volume'].plot.box()
# Out:
# <AxesSubplot:>

# %%
ds['4046'].plot.box()
# Out:
# <AxesSubplot:>

# %%
ds['4225'].plot.box()
# Out:
# <AxesSubplot:>

# %%
ds['4770'].plot.box()
# Out:
# <AxesSubplot:>

# %%
ds['Total Bags'].plot.box()
# Out:
# <AxesSubplot:>

# %%
ds['Small Bags'].plot.box()
# Out:
# <AxesSubplot:>

# %%
ds['Large Bags'].plot.box()
# Out:
# <AxesSubplot:>

# %%
ds['XLarge Bags'].plot.box()
# Out:
# <AxesSubplot:>

# %%
ds['type'].plot.box()
# Out:
# <AxesSubplot:>

# %%
ds['year'].plot.box()
# Out:
# <AxesSubplot:>

# %%
ds['region'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# From the above boxplot, we can see that outliers are present in some features.
#
# Now we will try to remove the ourliers with the help of zscore and IQR methods.

# %%
from scipy.stats import zscore
outliers=ds[['Unnamed: 0','Date','AveragePrice','Total Volume','4046','4225','4770','Total Bags','Small Bags','Large Bags','type','year','region']]
z=np.abs(zscore(outliers))
z
# Out:
#        Unnamed: 0      Date  AveragePrice  Total Volume      4046      4225  \
# 0        1.565327  0.676360      0.188689      0.275399  0.715829  0.173710
# 1        1.500730  0.696857      0.139020      0.334355  0.795270  0.094757
# 2        1.436133  0.717355      1.182069      0.031861  0.765596  0.471429
# 3        1.371536  0.737853      0.809551      0.195601  0.698883  0.289024
# 4        1.306939  0.758350      0.312861      0.360978  0.734126  0.087699
# ...           ...       ...           ...           ...       ...       ...
# 18244    1.113149  1.578371      0.556347      0.726346  0.577981  0.913422
# 18245    1.048552  1.557874      0.755023      0.788107  0.688860  0.720791
# 18246    0.983955  1.537376      1.152375      0.790683  0.688824  0.803977
# 18247    0.919358  1.516879      1.301382      0.742176  0.639200  0.756223
# 18248    0.854761  1.496381      0.531512      0.719032  0.501515  0.813629
#
# ...

# %% [markdown]
# As the zscore is not taking the 'Xlarge bags' column in consideration, it is better to drop it from the data.

# %%
np.where(z>3)
# Out:
# (array([ 2652,  2652,  2652, ..., 17304, 17402, 17428], dtype=int64),
#  array([3, 4, 5, ..., 2, 2, 2], dtype=int64))

# %%
z.iloc[2652,4]
# Out:
# 3.3999887706271115

# %%
ds1=ds[(z<3).all(axis=1)]
ds1
# Out:
#        Unnamed: 0  Date  AveragePrice  Total Volume      4046      4225  \
# 0               0    51          1.33      6.328447  3.181351  6.156579
# 1               1    50          1.35      6.164507  2.961238  5.955965
# 2               2    49          0.93      7.005653  3.043457  6.913061
# 3               3    48          1.08      6.550342  3.228304  6.449584
# 4               4    47          1.28      6.090476  3.130655  5.938031
# ...           ...   ...           ...           ...       ...       ...
# 18244           7   161          1.63      5.074494  3.563293  3.394252
# 18245           8   160          1.71      4.902755  3.256076  3.883715
# 18246           9   159          1.87      4.895593  3.256176  3.672344
# 18247          10   158          1.93      5.030477  3.393671  3.793685
# 18248          11   157          1.62      5.094832  3.775163  3.647818
#
#            4770  Total Bags  Small Bags  Large Bags  XLarge Bags  type  year  \
# ...

# %%
print('Old data shape',ds.shape)
print('New data shape',ds1.shape)
# Out:
# Old data shape (18249, 14)
# New data shape (17924, 14)

# %% [markdown]
# As we can see that, ZLarge bags is the empty column, it is better to drop it.

# %%
ds1.drop(['XLarge Bags'],axis=1,inplace=True)

# %%
ds1
# Out:
#        Unnamed: 0  Date  AveragePrice  Total Volume      4046      4225  \
# 0               0    51          1.33      6.328447  3.181351  6.156579
# 1               1    50          1.35      6.164507  2.961238  5.955965
# 2               2    49          0.93      7.005653  3.043457  6.913061
# 3               3    48          1.08      6.550342  3.228304  6.449584
# 4               4    47          1.28      6.090476  3.130655  5.938031
# ...           ...   ...           ...           ...       ...       ...
# 18244           7   161          1.63      5.074494  3.563293  3.394252
# 18245           8   160          1.71      4.902755  3.256076  3.883715
# 18246           9   159          1.87      4.895593  3.256176  3.672344
# 18247          10   158          1.93      5.030477  3.393671  3.793685
# 18248          11   157          1.62      5.094832  3.775163  3.647818
#
#            4770  Total Bags  Small Bags  Large Bags  type  year  region
# ...

# %%
print('Data loss percentage',((ds.shape[0]-ds1.shape[0])/ds.shape[0])*100)
# Out:
# Data loss percentage 1.7809195024384896

# %% [markdown]
# The above mentioned data loss affordable.

# %%
Q1=ds1.quantile(.25)
Q3=ds1.quantile(.75)
IQR=Q3-Q1
IQR
# Out:
# Unnamed: 0      28.000000
# Date            84.000000
# AveragePrice     0.560000
# Total Volume     3.950978
# 4046             3.812483
# 4225             3.430561
# 4770             4.255540
# Total Bags       1.041412
# Small Bags       2.816739
# Large Bags       3.010573
# type             1.000000
# year             2.000000
# region          26.000000
# dtype: float64

# %%
ds1_new=ds1[(z<3).all(axis=1)]
ds1_new
# Out:
#        Unnamed: 0  Date  AveragePrice  Total Volume      4046      4225  \
# 0               0    51          1.33      6.328447  3.181351  6.156579
# 1               1    50          1.35      6.164507  2.961238  5.955965
# 2               2    49          0.93      7.005653  3.043457  6.913061
# 3               3    48          1.08      6.550342  3.228304  6.449584
# 4               4    47          1.28      6.090476  3.130655  5.938031
# ...           ...   ...           ...           ...       ...       ...
# 18244           7   161          1.63      5.074494  3.563293  3.394252
# 18245           8   160          1.71      4.902755  3.256076  3.883715
# 18246           9   159          1.87      4.895593  3.256176  3.672344
# 18247          10   158          1.93      5.030477  3.393671  3.793685
# 18248          11   157          1.62      5.094832  3.775163  3.647818
#
#            4770  Total Bags  Small Bags  Large Bags  type  year  region
# ...

# %%
plt.figure(figsize=(25,20))
p=1
for i in outliers:
    if p<=18:
        ax=plt.subplot(5,4,p)
        sns.distplot(ds[i],color='r')
        plt.xlabel(i,fontsize=15)
    p+=1
plt.show()

# %% [markdown]
# Here, we have cleared all the outliers from the data using zscore and IQR method. We can see from the above plots, all the features are showing almost normal distribution.

# %%
plt.figure(figsize=(20,16))
plt.subplot(6,4,3)
sns.histplot(ds['AveragePrice'],kde=True)
plt.show()

# %%
plt.figure(figsize=(20,16))
plt.subplot(6,4,3)
sns.histplot(ds['region'],kde=True)
plt.show()

# %%
ds1_new.skew()
# Out:
# Unnamed: 0      0.101734
# Date            0.008546
# AveragePrice    0.389847
# Total Volume    0.600626
# 4046            0.601219
# 4225            0.414012
# 4770            0.458208
# Total Bags      0.270222
# Small Bags      0.357047
# Large Bags      0.101026
# type           -0.003794
# year            0.223145
# region          0.015831
# dtype: float64

# %%
sns.distplot(ds1_new['AveragePrice'],color='b',kde_kws={'shade':True},hist=False)
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='Density'>

# %%
sns.distplot(ds1_new['region'],color='b',kde_kws={'shade':True},hist=False)
# Out:
# <AxesSubplot:xlabel='region', ylabel='Density'>

# %%
ds1_new
# Out:
#        Unnamed: 0  Date  AveragePrice  Total Volume      4046      4225  \
# 0               0    51          1.33      6.328447  3.181351  6.156579
# 1               1    50          1.35      6.164507  2.961238  5.955965
# 2               2    49          0.93      7.005653  3.043457  6.913061
# 3               3    48          1.08      6.550342  3.228304  6.449584
# 4               4    47          1.28      6.090476  3.130655  5.938031
# ...           ...   ...           ...           ...       ...       ...
# 18244           7   161          1.63      5.074494  3.563293  3.394252
# 18245           8   160          1.71      4.902755  3.256076  3.883715
# 18246           9   159          1.87      4.895593  3.256176  3.672344
# 18247          10   158          1.93      5.030477  3.393671  3.793685
# 18248          11   157          1.62      5.094832  3.775163  3.647818
#
#            4770  Total Bags  Small Bags  Large Bags  type  year  region
# ...

# %%
ds1_new.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'type', 'year',
#        'region'],
#       dtype='object')

# %%
columns_new=['AveragePrice','region','Unnamed: 0', 'Date','Total Volume', '4046', '4225',
       '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'type', 'year']

# %%
ds1_new = ds1_new.reindex(columns=columns_new)
ds1_new
# Out:
#        AveragePrice  region  Unnamed: 0  Date  Total Volume      4046  \
# 0              1.33       0           0    51      6.328447  3.181351
# 1              1.35       0           1    50      6.164507  2.961238
# 2              0.93       0           2    49      7.005653  3.043457
# 3              1.08       0           3    48      6.550342  3.228304
# 4              1.28       0           4    47      6.090476  3.130655
# ...             ...     ...         ...   ...           ...       ...
# 18244          1.63      53           7   161      5.074494  3.563293
# 18245          1.71      53           8   160      4.902755  3.256076
# 18246          1.87      53           9   159      4.895593  3.256176
# 18247          1.93      53          10   158      5.030477  3.393671
# 18248          1.62      53          11   157      5.094832  3.775163
#
#            4225      4770  Total Bags  Small Bags  Large Bags  type  year
# ...

# %%
x=ds1_new.iloc[:,2:]
x
# Out:
#        Unnamed: 0  Date  Total Volume      4046      4225      4770  \
# 0               0    51      6.328447  3.181351  6.156579  1.907426
# 1               1    50      6.164507  2.961238  5.955965  1.969316
# 2               2    49      7.005653  3.043457  6.913061  2.252173
# 3               3    48      6.550342  3.228304  6.449584  2.042378
# 4               4    47      6.090476  3.130655  5.938031  2.057118
# ...           ...   ...           ...       ...       ...       ...
# 18244           7   161      5.074494  3.563293  3.394252  0.000000
# 18245           8   160      4.902755  3.256076  3.883715  0.000000
# 18246           9   159      4.895593  3.256176  3.672344  2.999273
# 18247          10   158      5.030477  3.393671  3.793685  2.998634
# 18248          11   157      5.094832  3.775163  3.647818  2.465353
#
#        Total Bags  Small Bags  Large Bags  type  year
# 0        2.739725    4.526684    2.129486     0     0
# ...

# %%
y=ds1_new.iloc[:,0:2]
y
# Out:
#        AveragePrice  region
# 0              1.33       0
# 1              1.35       0
# 2              0.93       0
# 3              1.08       0
# 4              1.28       0
# ...             ...     ...
# 18244          1.63      53
# 18245          1.71      53
# 18246          1.87      53
# 18247          1.93      53
# 18248          1.62      53
#
# [17924 rows x 2 columns]

# %%
x.shape
# Out:
# (17924, 11)

# %%
y.shape
# Out:
# (17924, 2)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif=pd.DataFrame()
vif['VIF values']=[variance_inflation_factor(x.values,i)for i in range(len(x.columns))]
vif['Features']=x.columns
vif
# Out:
#     VIF values      Features
# 0     9.823021    Unnamed: 0
# 1   114.132525          Date
# 2   748.911287  Total Volume
# 3    52.380162          4046
# 4   121.588758          4225
# 5     9.232975          4770
# 6   358.185988    Total Bags
# 7   112.013776    Small Bags
# 8    10.033560    Large Bags
# 9     4.676080          type
# 10   59.453952          year

# %% [markdown]
# As we can see from the above VIF values, 'Date','4225' columns are highly correlated with each other, so we can drop those columns alongwith 'Total Volume' and 'Total Bags' columns.

# %%
ds1_new.drop(['Date','4225','Total Bags','Total Volume'],axis=1,inplace=True)

# %%
ds1_new
# Out:
#        AveragePrice  region  Unnamed: 0      4046      4770  Small Bags  \
# 0              1.33       0           0  3.181351  1.907426    4.526684
# 1              1.35       0           1  2.961238  1.969316    4.594625
# 2              0.93       0           2  3.043457  2.252173    4.476060
# 3              1.08       0           3  3.228304  2.042378    4.223686
# 4              1.28       0           4  3.130655  2.057118    4.261141
# ...             ...     ...         ...       ...       ...         ...
# 18244          1.63      53           7  3.563293  0.000000    4.853201
# 18245          1.71      53           8  3.256076  0.000000    4.555715
# 18246          1.87      53           9  3.256176  2.999273    4.590034
# 18247          1.93      53          10  3.393671  2.998634    4.710143
# 18248          1.62      53          11  3.775163  2.465353    4.784009
#
#        Large Bags  type  year
# 0        2.129486     0     0
# 1        2.145326     0     0
# ...

# %%
x1=ds1_new.iloc[:,2:]
x1
# Out:
#        Unnamed: 0      4046      4770  Small Bags  Large Bags  type  year
# 0               0  3.181351  1.907426    4.526684    2.129486     0     0
# 1               1  2.961238  1.969316    4.594625    2.145326     0     0
# 2               2  3.043457  2.252173    4.476060    2.165565     0     0
# 3               3  3.228304  2.042378    4.223686    2.261454     0     0
# 4               4  3.130655  2.057118    4.261141    2.413593     0     0
# ...           ...       ...       ...         ...         ...   ...   ...
# 18244           7  3.563293  0.000000    4.853201    2.749300     1     3
# 18245           8  3.256076  0.000000    4.555715    2.621819     1     3
# 18246           9  3.256176  2.999273    4.590034    1.866697     1     3
# 18247          10  3.393671  2.998634    4.710143    1.919383     1     3
# 18248          11  3.775163  2.465353    4.784009    1.721301     1     3
#
# [17924 rows x 7 columns]

# %%
y1=ds1_new.iloc[:,0:2]
y1
# Out:
#        AveragePrice  region
# 0              1.33       0
# 1              1.35       0
# 2              0.93       0
# 3              1.08       0
# 4              1.28       0
# ...             ...     ...
# 18244          1.63      53
# 18245          1.71      53
# 18246          1.87      53
# 18247          1.93      53
# 18248          1.62      53
#
# [17924 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.metrics import mean_absolute_error,mean_squared_error, r2_score

# %%
x1_train,x1_test,y1_train,y1_test=train_test_split(x1,y1,test_size=.30,random_state=42)

# %%
x1_train.shape
# Out:
# (12546, 7)

# %%
x1_test.shape
# Out:
# (5378, 7)

# %%
y1_train.shape
# Out:
# (12546, 2)

# %%
y1_test.shape
# Out:
# (5378, 2)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x1_train,y1_train)
pred_lr=lr.predict(x1_test)
pred_lr
# Out:
# array([[ 1.14610436, 27.13832931],
#        [ 1.51273666, 28.39147023],
#        [ 1.05507486, 26.62192262],
#        ...,
#        [ 1.61222868, 27.20412432],
#        [ 1.20164546, 24.01842495],
#        [ 1.58620192, 26.3202683 ]])

# %%
print('r2 score:',r2_score(y1_test,pred_lr))
print('mean_squared_error:', mean_squared_error(y1_test,pred_lr))
print('root mean_squared_error:',np.sqrt(mean_squared_error(y1_test,pred_lr)))
# Out:
# r2 score: 0.27302468960140275
# mean_squared_error: 110.30081066647672
# root mean_squared_error: 10.502419276836967

# %%
from sklearn.ensemble import RandomForestRegressor
rfr=RandomForestRegressor()
rfr.fit(x1_train,y1_train)
pred_rfr=rfr.predict(x1_test)
pred_rfr
# Out:
# array([[ 1.1948, 42.03  ],
#        [ 1.3497, 42.48  ],
#        [ 0.8393, 37.61  ],
#        ...,
#        [ 1.9628, 28.65  ],
#        [ 1.1615, 22.48  ],
#        [ 1.6382, 34.94  ]])

# %%
print('r2 score:',r2_score(y1_test,pred_rfr))
print('mean_squared_error:', mean_squared_error(y1_test,pred_rfr))
print('root mean_squared_error:',np.sqrt(mean_squared_error(y1_test,pred_rfr)))
# Out:
# r2 score: 0.7237865449347725
# mean_squared_error: 39.37319517007625
# root mean_squared_error: 6.274806385066893

# %%
from sklearn.neighbors import KNeighborsRegressor
knn=KNeighborsRegressor()
knn.fit(x1_train,y1_train)
pred_knn=knn.predict(x1_test)
pred_knn
# Out:
# array([[ 0.96 , 37.6  ],
#        [ 1.348, 40.2  ],
#        [ 0.942, 25.2  ],
#        ...,
#        [ 1.912, 28.2  ],
#        [ 1.2  , 33.4  ],
#        [ 1.66 , 35.4  ]])

# %%
print('r2 score:',r2_score(y1_test,pred_knn))
print('mean_squared_error:', mean_squared_error(y1_test,pred_knn))
print('root mean_squared_error:',np.sqrt(mean_squared_error(y1_test,pred_knn)))
# Out:
# r2 score: 0.4952384508479821
# mean_squared_error: 84.13954476719924
# root mean_squared_error: 9.172761022025988

# %%
from sklearn.linear_model import Lasso
ls=Lasso()
ls.fit(x1_train,y1_train)
pred_ls=ls.predict(x1_test)
pred_ls
# Out:
# array([[ 1.39802168, 27.94908036],
#        [ 1.39802168, 26.38886258],
#        [ 1.39802168, 27.61648113],
#        ...,
#        [ 1.39802168, 25.11799698],
#        [ 1.39802168, 26.84610186],
#        [ 1.39802168, 24.08878162]])

# %%
print('r2 score:',r2_score(y1_test,pred_ls))
print('mean_squared_error:', mean_squared_error(y1_test,pred_ls))
print('root mean_squared_error:',np.sqrt(mean_squared_error(y1_test,pred_ls)))
# Out:
# r2 score: 0.02329559646107876
# mean_squared_error: 112.7157947666822
# root mean_squared_error: 10.61676950709029

# %%
from sklearn.linear_model import Ridge
rdg=Ridge()
rdg.fit(x1_train,y1_train)
pred_rdg=rdg.predict(x1_test)
pred_rdg
# Out:
# array([[ 1.14613778, 27.13880152],
#        [ 1.51272238, 28.391142  ],
#        [ 1.05509266, 26.62231683],
#        ...,
#        [ 1.61201988, 27.20067337],
#        [ 1.20179434, 24.0209425 ],
#        [ 1.5861351 , 26.31907836]])

# %%
print('r2 score:',r2_score(y1_test,pred_rdg))
print('mean_squared_error:', mean_squared_error(y1_test,pred_rdg))
print('root mean_squared_error:',np.sqrt(mean_squared_error(y1_test,pred_rdg)))
# Out:
# r2 score: 0.2730257659461445
# mean_squared_error: 110.30041417021259
# root mean_squared_error: 10.502400400394787

# %%
from sklearn.tree import DecisionTreeRegressor
dtr=DecisionTreeRegressor()
dtr.fit(x1_train,y1_train)
pred_dtr=dtr.predict(x1_test)
pred_dtr
# Out:
# array([[ 1.1 , 36.  ],
#        [ 1.42, 41.  ],
#        [ 0.7 , 41.  ],
#        ...,
#        [ 1.81, 29.  ],
#        [ 1.16, 16.  ],
#        [ 1.87, 43.  ]])

# %%
print('r2 score:',r2_score(y1_test,pred_dtr))
print('mean_squared_error:', mean_squared_error(y1_test,pred_dtr))
print('root mean_squared_error:',np.sqrt(mean_squared_error(y1_test,pred_dtr)))
# Out:
# r2 score: 0.42598078809206
# mean_squared_error: 79.25955500185944
# root mean_squared_error: 8.902783553578029

# %%
from sklearn.ensemble import ExtraTreesRegressor
etr=ExtraTreesRegressor()
etr.fit(x1_train,y1_train)
pred_etr=etr.predict(x1_test)
pred_etr
# Out:
# array([[ 1.1054, 40.02  ],
#        [ 1.2475, 40.11  ],
#        [ 0.9037, 39.59  ],
#        ...,
#        [ 2.0396, 29.45  ],
#        [ 1.1437, 17.67  ],
#        [ 1.5819, 31.08  ]])

# %%
print('r2 score:',r2_score(y1_test,pred_etr))
print('mean_squared_error:', mean_squared_error(y1_test,pred_etr))
print('root mean_squared_error:',np.sqrt(mean_squared_error(y1_test,pred_etr)))
# Out:
# r2 score: 0.7804191912222722
# mean_squared_error: 31.53289903127275
# root mean_squared_error: 5.615416193949719

# %% [markdown]
# From the above model fitting and performance score, we can say that, ExtraTreeRegressor is the best fitting and best performing models,which is giving a performance score as 89.11.

# %%
from sklearn.model_selection import cross_val_score

# %%
score= cross_val_score(lr,x,y,cv=5,scoring='r2')
print(score)
print(score.mean())
print('Difference between r2 score and cross validation score is-',(r2_score(pred_lr,y1_test)) - (score.mean()*100))
# Out:
# [-0.15290182  0.1067104  -0.22920988 -0.03477415  0.16431856]
# -0.02917137807257263
# Difference between r2 score and cross validation score is- -2.932262011401182

# %%
score1= cross_val_score(knn,x,y,cv=5,scoring='r2')
print(score1)
print(score1.mean())
print('Difference between r2 score and cross validation score is-',(r2_score(pred_rfr,y1_test)) - (score.mean()*100))
# Out:
# [-3.16304444 -1.05641934 -1.08435575 -1.14373843 -0.53695303]
# -1.396902196540673
# Difference between r2 score and cross validation score is- 3.4653208626156973

# %%
score2= cross_val_score(knn,x,y,cv=5,scoring='r2')
print(score2)
print(score2.mean())
print('Difference between r2 score and cross validation score is-',(r2_score(pred_knn,y1_test)) - (score.mean()*100))
# Out:
# [-3.16304444 -1.05641934 -1.08435575 -1.14373843 -0.53695303]
# -1.396902196540673
# Difference between r2 score and cross validation score is- 2.724577905379219

# %%
score4= cross_val_score(ls,x,y,cv=5,scoring='r2')
print(score4)
print(score4.mean())
print('Difference between r2 score and cross validation score is-',(r2_score(pred_ls,y1_test)) - (score.mean()*100))
# Out:
# [-2.14975882 -0.41557287 -0.71070186 -0.47689117 -0.44494135]
# -0.8395732161233942
# Difference between r2 score and cross validation score is- -9.572577361483563e+24

# %%
score5= cross_val_score(rdg,x,y,cv=5,scoring='r2')
print(score5)
print(score5.mean())
print('Difference between r2 score and cross validation score is-',(r2_score(pred_rdg,y1_test)) - (score.mean()*100))
# Out:
# [-0.15300687  0.1066526  -0.22898718 -0.0345279   0.1642232 ]
# -0.029129230197751856
# Difference between r2 score and cross validation score is- -2.935309139654964

# %%
score6= cross_val_score(dtr,x,y,cv=5,scoring='r2')
print(score6)
print(score6.mean())
print('Difference between r2 score and cross validation score is-',(r2_score(pred_dtr,y1_test)) - (score.mean()*100))
# Out:
# [-0.61042101 -1.20041257 -1.05382115 -0.93810563 -0.39051709]
# -0.8386554905855187
# Difference between r2 score and cross validation score is- 3.340444096225546

# %%
score7= cross_val_score(etr,x,y,cv=5,scoring='r2')
print(score7)
print(score7.mean())
print('Difference between r2 score and cross validation score is-',(r2_score(pred_etr,y1_test)) - (score.mean()*100))
# Out:
# [-0.03389134 -1.20061217 -0.87249376 -0.68127552  0.2254661 ]
# -0.5125613374091949
# Difference between r2 score and cross validation score is- 3.5787549306558977

# %%
import pickle

# %%
filename='Avocado.pkl'
pickle.dump(etr,open('Avocado.pkl','wb'))

# %%
loaded_model=pickle.load(open('Avocado.pkl','rb'))
result=loaded_model.score(x1_test,y1_test)
print(result*100)
# Out:
# 78.04191912222723

# %%
conclusion=pd.DataFrame([loaded_model.predict(x1_test)[:],(y1_test)[0:2]],index=['Predicted','Original'])
conclusion
# Out:
#                                                            0
# Predicted  [[1.1053999999999997, 40.02], [1.2475000000000...
# Original          AveragePrice  region
# 2270           1.0...

# %%
def pred_etr(p):
    p=p.reshape(1,-1)
    pred=etr.predict(p)
    print('Response type',pred)

# %%
p=np.array([4,3.130655,2.057118,4.261141,2.413593,0,0])
pred_etr(p)
# Out:
# Response type [[1.28 0.  ]]
